# %%
#To see if Git is succesfully uploaded into the computer
# !git --version
# Out:
# git version 2.45.2.windows.1

# %%
import matplotlib.pyplot as plt

# Disable LaTeX
plt.rcParams['text.usetex'] = False

# Optionally, configure the font to avoid using LaTeX-style fonts
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Arial']

# %%
import matplotlib.pyplot as plt

# Disable LaTeX
plt.rcParams['text.usetex'] = False

# %%
#Cloning the repository
# !git clone https://github.com/GabrielaCR/AGNfitter.git
# Out:
# fatal: destination path 'AGNfitter' already exists and is not an empty directory.

# %%
#Changing to the cloned directory
import os
os.chdir('AGNfitter')

# %%
import acor

# %%
# !pip install numpy scipy astropy emcee
# Out:
# Requirement already satisfied: numpy in c:\users\pc\anaconda3\lib\site-packages (1.24.3)
# Requirement already satisfied: scipy in c:\users\pc\anaconda3\lib\site-packages (1.11.1)
# Requirement already satisfied: astropy in c:\users\pc\anaconda3\lib\site-packages (5.1)
# Requirement already satisfied: emcee in c:\users\pc\anaconda3\lib\site-packages (3.1.6)
# Requirement already satisfied: pyerfa>=2.0 in c:\users\pc\anaconda3\lib\site-packages (from astropy) (2.0.0)
# Requirement already satisfied: PyYAML>=3.13 in c:\users\pc\anaconda3\lib\site-packages (from astropy) (6.0)
# Requirement already satisfied: packaging>=19.0 in c:\users\pc\anaconda3\lib\site-packages (from astropy) (23.1)
# DEPRECATION: Loading egg at c:\users\pc\anaconda3\lib\site-packages\fonttools-4.53.0-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\users\pc\anaconda3\lib\site-packages\ultranest-4.3.1-py3.11-win-amd64.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..

# %%
#Listing the contents of the current directory 
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is A2A0-BBAD
#
#  Directory of C:\Users\PC\AGNfitter
#
# 07/03/2024  10:42 PM    <DIR>          .
# 07/03/2024  10:40 PM    <DIR>          ..
# 07/03/2024  07:52 PM    <DIR>          -p
# 07/02/2024  03:38 PM               907 .gitignore
# 07/03/2024  07:26 PM    <DIR>          .ipynb_checkpoints
# 07/02/2024  03:38 PM               191 .readthedocs.yaml
# 07/02/2024  04:41 PM    <DIR>          acor
# 07/02/2024  03:38 PM             3,792 catalog_example.txt
# 07/02/2024  03:38 PM    <DIR>          data
# 07/02/2024  03:38 PM    <DIR>          docs
# 07/02/2024  03:38 PM                 0 error.log
# 07/02/2024  08:04 PM    <DIR>          example
# 07/03/2024  10:15 PM    <DIR>          functions
# 07/02/2024  03:38 PM             1,112 LICENSE
# 07/02/2024  03:38 PM    <DIR>          models
# 07/03/2024  10:16 PM    <DIR>          OUTPUT
# 07/02/2024  03:38 PM             5,616 README.md
# 07/02/2024  03:38 PM             1,069 readthedocs.yaml
# 07/03/2024  10:42 PM            14,266 RUN_AGNfitter_multi.py
# 07/03/2024  07:54 PM             5,573 SETTINGS_AGNfitter.py
# 07/03/2024  08:59 PM    <DIR>          UltraNest
# 07/03/2024  07:28 PM            20,455 Untitled.ipynb
#               10 File(s)         52,981 bytes
#               12 Dir(s)  924,965,855,232 bytes free

# %%
# !git clone https://github.com/dfm/acor.git
# Out:
# fatal: destination path 'acor' already exists and is not an empty directory.

# %%
import os
os.chdir('C:\\Users\\PC\\AGNfitter')  # Change to your AGNfitter directory
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is A2A0-BBAD
#
#  Directory of C:\Users\PC\AGNfitter
#
# 07/03/2024  10:42 PM    <DIR>          .
# 07/03/2024  10:40 PM    <DIR>          ..
# 07/03/2024  07:52 PM    <DIR>          -p
# 07/02/2024  03:38 PM               907 .gitignore
# 07/03/2024  07:26 PM    <DIR>          .ipynb_checkpoints
# 07/02/2024  03:38 PM               191 .readthedocs.yaml
# 07/02/2024  04:41 PM    <DIR>          acor
# 07/02/2024  03:38 PM             3,792 catalog_example.txt
# 07/02/2024  03:38 PM    <DIR>          data
# 07/02/2024  03:38 PM    <DIR>          docs
# 07/02/2024  03:38 PM                 0 error.log
# 07/02/2024  08:04 PM    <DIR>          example
# 07/03/2024  10:15 PM    <DIR>          functions
# 07/02/2024  03:38 PM             1,112 LICENSE
# 07/02/2024  03:38 PM    <DIR>          models
# 07/03/2024  10:16 PM    <DIR>          OUTPUT
# 07/02/2024  03:38 PM             5,616 README.md
# 07/02/2024  03:38 PM             1,069 readthedocs.yaml
# 07/03/2024  10:42 PM            14,266 RUN_AGNfitter_multi.py
# 07/03/2024  07:54 PM             5,573 SETTINGS_AGNfitter.py
# 07/03/2024  08:59 PM    <DIR>          UltraNest
# 07/03/2024  07:28 PM            20,455 Untitled.ipynb
#               10 File(s)         52,981 bytes
#               12 Dir(s)  924,965,855,232 bytes free

# %%
import sys
sys.path.append(os.path.join(os.getcwd(), 'acor'))

# %%
# !git clone https://github.com/JohannesBuchner/UltraNest.git
# Out:
# fatal: destination path 'UltraNest' already exists and is not an empty directory.

# %%
import os
os.chdir('UltraNest')

# %%
# !python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# writing ultranest.egg-info\PKG-INFO
# writing dependency_links to ultranest.egg-info\dependency_links.txt
# writing requirements to ultranest.egg-info\requires.txt
# writing top-level names to ultranest.egg-info\top_level.txt
# reading manifest file 'ultranest.egg-info\SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# adding license file 'LICENSE'
# writing manifest file 'ultranest.egg-info\SOURCES.txt'
# installing library code to build\bdist.win-amd64\egg
# running install_lib
# running build_py
# running build_ext
# creating build\bdist.win-amd64\egg
# creating build\bdist.win-amd64\egg\ultranest
# copying build\lib.win-amd64-cpython-311\ultranest\calibrator.py -> build\bdist.win-amd64\egg\ultranest
# copying build\lib.win-amd64-cpython-311\ultranest\dychmc.py -> build\bdist.win-amd64\egg\ultranest
# copying build\lib.win-amd64-cpython-311\ultranest\dyhmc.py -> build\bdist.win-amd64\egg\ultranest
# copying build\lib.win-amd64-cpython-311\ultranest\flatnuts.py -> build\bdist.win-amd64\egg\ultranest
# copying build\lib.win-amd64-cpython-311\ultranest\hotstart.py -> build\bdist.win-amd64\egg\ultranest
# copying build\lib.win-amd64-cpython-311\ultranest\integrator.py -> build\bdist.win-amd64\egg\ultranest
# copying build\lib.win-amd64-cpython-311\ultranest\mlfriends.c -> build\bdist.win-amd64\egg\ultranest
# copying build\lib.win-amd64-cpython-311\ultranest\mlfriends.cp311-win_amd64.pyd -> build\bdist.win-amd64\egg\ultranest
# copying build\lib.win-amd64-cpython-311\ultranest\mlfriends.pyx -> build\bdist.win-amd64\egg\ultranest
# copying build\lib.win-amd64-cpython-311\ultranest\netiter.py -> build\bdist.win-amd64\egg\ultranest
# copying build\lib.win-amd64-cpython-311\ultranest\ordertest.py -> build\bdist.win-amd64\egg\ultranest
# copying build\lib.win-amd64-cpython-311\ultranest\pathsampler.py -> build\bdist.win-amd64\egg\ultranest
# copying build\lib.win-amd64-cpython-311\ultranest\plot.py -> build\bdist.win-amd64\egg\ultranest
# copying build\lib.win-amd64-cpython-311\ultranest\popstepsampler.py -> build\bdist.win-amd64\egg\ultranest
# copying build\lib.win-amd64-cpython-311\ultranest\samplingpath.py -> build\bdist.win-amd64\egg\ultranest
# copying build\lib.win-amd64-cpython-311\ultranest\solvecompat.py -> build\bdist.win-amd64\egg\ultranest
# copying build\lib.win-amd64-cpython-311\ultranest\stepfuncs.c -> build\bdist.win-amd64\egg\ultranest
# copying build\lib.win-amd64-cpython-311\ultranest\stepfuncs.cp311-win_amd64.pyd -> build\bdist.win-amd64\egg\ultranest
# copying build\lib.win-amd64-cpython-311\ultranest\stepfuncs.pyx -> build\bdist.win-amd64\egg\ultranest
# copying build\lib.win-amd64-cpython-311\ultranest\stepsampler.py -> build\bdist.win-amd64\egg\ultranest
# copying build\lib.win-amd64-cpython-311\ultranest\store.py -> build\bdist.win-amd64\egg\ultranest
# copying build\lib.win-amd64-cpython-311\ultranest\utils.py -> build\bdist.win-amd64\egg\ultranest
# copying build\lib.win-amd64-cpython-311\ultranest\viz.py -> build\bdist.win-amd64\egg\ultranest
# copying build\lib.win-amd64-cpython-311\ultranest\__init__.py -> build\bdist.win-amd64\egg\ultranest
# byte-compiling build\bdist.win-amd64\egg\ultranest\calibrator.py to calibrator.cpython-311.pyc
# byte-compiling build\bdist.win-amd64\egg\ultranest\dychmc.py to dychmc.cpython-311.pyc
# byte-compiling build\bdist.win-amd64\egg\ultranest\dyhmc.py to dyhmc.cpython-311.pyc
# byte-compiling build\bdist.win-amd64\egg\ultranest\flatnuts.py to flatnuts.cpython-311.pyc
# byte-compiling build\bdist.win-amd64\egg\ultranest\hotstart.py to hotstart.cpython-311.pyc
# byte-compiling build\bdist.win-amd64\egg\ultranest\integrator.py to integrator.cpython-311.pyc
# byte-compiling build\bdist.win-amd64\egg\ultranest\netiter.py to netiter.cpython-311.pyc
# byte-compiling build\bdist.win-amd64\egg\ultranest\ordertest.py to ordertest.cpython-311.pyc
# byte-compiling build\bdist.win-amd64\egg\ultranest\pathsampler.py to pathsampler.cpython-311.pyc
# byte-compiling build\bdist.win-amd64\egg\ultranest\plot.py to plot.cpython-311.pyc
# byte-compiling build\bdist.win-amd64\egg\ultranest\popstepsampler.py to popstepsampler.cpython-311.pyc
# byte-compiling build\bdist.win-amd64\egg\ultranest\samplingpath.py to samplingpath.cpython-311.pyc
# byte-compiling build\bdist.win-amd64\egg\ultranest\solvecompat.py to solvecompat.cpython-311.pyc
# byte-compiling build\bdist.win-amd64\egg\ultranest\stepsampler.py to stepsampler.cpython-311.pyc
# byte-compiling build\bdist.win-amd64\egg\ultranest\store.py to store.cpython-311.pyc
# byte-compiling build\bdist.win-amd64\egg\ultranest\utils.py to utils.cpython-311.pyc
# byte-compiling build\bdist.win-amd64\egg\ultranest\viz.py to viz.cpython-311.pyc
# byte-compiling build\bdist.win-amd64\egg\ultranest\__init__.py to __init__.cpython-311.pyc
# creating stub loader for ultranest\mlfriends.cp311-win_amd64.pyd
# creating stub loader for ultranest\stepfuncs.cp311-win_amd64.pyd
# byte-compiling build\bdist.win-amd64\egg\ultranest\mlfriends.py to mlfriends.cpython-311.pyc
# byte-compiling build\bdist.win-amd64\egg\ultranest\stepfuncs.py to stepfuncs.cpython-311.pyc
# creating build\bdist.win-amd64\egg\EGG-INFO
# copying ultranest.egg-info\PKG-INFO -> build\bdist.win-amd64\egg\EGG-INFO
# copying ultranest.egg-info\SOURCES.txt -> build\bdist.win-amd64\egg\EGG-INFO
# copying ultranest.egg-info\dependency_links.txt -> build\bdist.win-amd64\egg\EGG-INFO
# copying ultranest.egg-info\not-zip-safe -> build\bdist.win-amd64\egg\EGG-INFO
# copying ultranest.egg-info\requires.txt -> build\bdist.win-amd64\egg\EGG-INFO
# copying ultranest.egg-info\top_level.txt -> build\bdist.win-amd64\egg\EGG-INFO
# writing build\bdist.win-amd64\egg\EGG-INFO\native_libs.txt
# creating 'dist\ultranest-4.3.1-py3.11-win-amd64.egg' and adding 'build\bdist.win-amd64\egg' to it
# removing 'build\bdist.win-amd64\egg' (and everything under it)
# Processing ultranest-4.3.1-py3.11-win-amd64.egg
# removing 'c:\users\pc\anaconda3\lib\site-packages\ultranest-4.3.1-py3.11-win-amd64.egg' (and everything under it)
# creating c:\users\pc\anaconda3\lib\site-packages\ultranest-4.3.1-py3.11-win-amd64.egg
# Extracting ultranest-4.3.1-py3.11-win-amd64.egg to c:\users\pc\anaconda3\lib\site-packages
# Adding ultranest 4.3.1 to easy-install.pth file
#
# Installed c:\users\pc\anaconda3\lib\site-packages\ultranest-4.3.1-py3.11-win-amd64.egg
# Processing dependencies for ultranest==4.3.1
# Searching for corner==2.2.2
# Best match: corner 2.2.2
# Adding corner 2.2.2 to easy-install.pth file
#
# Using c:\users\pc\anaconda3\lib\site-packages
# Searching for matplotlib==3.7.2
# Best match: matplotlib 3.7.2
# Adding matplotlib 3.7.2 to easy-install.pth file
#
# Using c:\users\pc\anaconda3\lib\site-packages
# Searching for Cython==3.0.10
# Best match: Cython 3.0.10
# Adding Cython 3.0.10 to easy-install.pth file
# Installing cygdb-script.py script to C:\Users\PC\anaconda3\Scripts
# Installing cygdb.exe script to C:\Users\PC\anaconda3\Scripts
# Installing cython-script.py script to C:\Users\PC\anaconda3\Scripts
# Installing cython.exe script to C:\Users\PC\anaconda3\Scripts
# Installing cythonize-script.py script to C:\Users\PC\anaconda3\Scripts
# Installing cythonize.exe script to C:\Users\PC\anaconda3\Scripts
#
# Using c:\users\pc\anaconda3\lib\site-packages
# Searching for numpy==1.24.3
# Best match: numpy 1.24.3
# Adding numpy 1.24.3 to easy-install.pth file
# Installing f2py-script.py script to C:\Users\PC\anaconda3\Scripts
# Installing f2py.exe script to C:\Users\PC\anaconda3\Scripts
#
# Using c:\users\pc\anaconda3\lib\site-packages
# Searching for python-dateutil==2.8.2
# Best match: python-dateutil 2.8.2
# Adding python-dateutil 2.8.2 to easy-install.pth file
#
# Using c:\users\pc\anaconda3\lib\site-packages
# Searching for pyparsing==3.0.9
# Best match: pyparsing 3.0.9
# Adding pyparsing 3.0.9 to easy-install.pth file
#
# Using c:\users\pc\anaconda3\lib\site-packages
# Searching for Pillow==9.4.0
# Best match: Pillow 9.4.0
# Adding Pillow 9.4.0 to easy-install.pth file
#
# Using c:\users\pc\anaconda3\lib\site-packages
# Searching for packaging==23.1
# Best match: packaging 23.1
# Adding packaging 23.1 to easy-install.pth file
#
# Using c:\users\pc\anaconda3\lib\site-packages
# Searching for kiwisolver==1.4.4
# Best match: kiwisolver 1.4.4
# Adding kiwisolver 1.4.4 to easy-install.pth file
#
# Using c:\users\pc\anaconda3\lib\site-packages
# Searching for fonttools==4.53.0
# Best match: fonttools 4.53.0
# Processing fonttools-4.53.0-py3.11.egg
# Adding fonttools 4.53.0 to easy-install.pth file
# Installing fonttools-script.py script to C:\Users\PC\anaconda3\Scripts
# Installing fonttools.exe script to C:\Users\PC\anaconda3\Scripts
# Installing pyftmerge-script.py script to C:\Users\PC\anaconda3\Scripts
# Installing pyftmerge.exe script to C:\Users\PC\anaconda3\Scripts
# Installing pyftsubset-script.py script to C:\Users\PC\anaconda3\Scripts
# Installing pyftsubset.exe script to C:\Users\PC\anaconda3\Scripts
# Installing ttx-script.py script to C:\Users\PC\anaconda3\Scripts
# Installing ttx.exe script to C:\Users\PC\anaconda3\Scripts
#
# Using c:\users\pc\anaconda3\lib\site-packages\fonttools-4.53.0-py3.11.egg
# Searching for cycler==0.11.0
# Best match: cycler 0.11.0
# Adding cycler 0.11.0 to easy-install.pth file
#
# Using c:\users\pc\anaconda3\lib\site-packages
# Searching for contourpy==1.0.5
# Best match: contourpy 1.0.5
# Adding contourpy 1.0.5 to easy-install.pth file
#
# Using c:\users\pc\anaconda3\lib\site-packages
# Searching for six==1.16.0
# Best match: six 1.16.0
# Adding six 1.16.0 to easy-install.pth file
#
# Using c:\users\pc\anaconda3\lib\site-packages
# Finished processing dependencies for ultranest==4.3.1
# C:\Users\PC\anaconda3\Lib\site-packages\setuptools\__init__.py:84: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
# !!
#
#         ********************************************************************************
#         Requirements should be satisfied by a PEP 517 installer.
#         If you are using pip, you can try `pip install --use-pep517`.
#         ********************************************************************************
#
# !!
#   dist.fetch_build_eggs(dist.setup_requires)
# C:\Users\PC\anaconda3\Lib\site-packages\setuptools\_distutils\cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# C:\Users\PC\anaconda3\Lib\site-packages\setuptools\_distutils\cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# warning: no files found matching 'requirements_dev.txt'
# warning: no files found matching '*.pxd' under directory '*'
# warning: no previously-included files matching '__pycache__' found under directory '*'
# warning: no previously-included files matching '*.py[co]' found under directory '*'
# warning: no previously-included files matching '*.orig' found under directory '*'
# warning: no previously-included files matching '*.pdf' found under directory '*'
# warning: no files found matching '*.png' under directory 'docs'
# no previously-included directories found matching 'tests\reports'
# no previously-included directories found matching 'tests\.pytype'
# warning: no previously-included files matching 'conetestdata.npz' found under directory 'tests'
# warning: no previously-included files matching 'region-stuck*.npz' found under directory 'tests'

# %%
# !pip install --upgrade pip setuptools wheel
# Out:
# Requirement already satisfied: pip in c:\users\pc\anaconda3\lib\site-packages (23.2.1)
# Collecting pip
#   Obtaining dependency information for pip from https://files.pythonhosted.org/packages/f4/ab/e3c039b5ddba9335bd8f82d599eb310de1d2a2db0411b8d804d507405c74/pip-24.1.1-py3-none-any.whl.metadata
#   Using cached pip-24.1.1-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: setuptools in c:\users\pc\anaconda3\lib\site-packages (68.0.0)
# Collecting setuptools
#   Obtaining dependency information for setuptools from https://files.pythonhosted.org/packages/42/54/2a8ecfcc9a714a6fbf86559a4b0f50b126a4ac4269ea8134f2c75c3e73de/setuptools-70.2.0-py3-none-any.whl.metadata
#   Using cached setuptools-70.2.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: wheel in c:\users\pc\anaconda3\lib\site-packages (0.38.4)
# Collecting wheel
#   Obtaining dependency information for wheel from https://files.pythonhosted.org/packages/7d/cd/d7460c9a869b16c3dd4e1e403cce337df165368c71d6af229a74699622ce/wheel-0.43.0-py3-none-any.whl.metadata
#   Using cached wheel-0.43.0-py3-none-any.whl.metadata (2.2 kB)
# Using cached pip-24.1.1-py3-none-any.whl (1.8 MB)
# Using cached setuptools-70.2.0-py3-none-any.whl (930 kB)
# Using cached wheel-0.43.0-py3-none-any.whl (65 kB)
# DEPRECATION: Loading egg at c:\users\pc\anaconda3\lib\site-packages\fonttools-4.53.0-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\users\pc\anaconda3\lib\site-packages\ultranest-4.3.1-py3.11-win-amd64.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# ERROR: To modify pip, please run the following command:
# C:\Users\PC\anaconda3\python.exe -m pip install --upgrade pip setuptools wheel

# %%
# !pip install Cython
# Out:
# Requirement already satisfied: Cython in c:\users\pc\anaconda3\lib\site-packages (3.0.10)
# DEPRECATION: Loading egg at c:\users\pc\anaconda3\lib\site-packages\fonttools-4.53.0-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\users\pc\anaconda3\lib\site-packages\ultranest-4.3.1-py3.11-win-amd64.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..

# %%
# !pip install --use-pep517 ultranest
# Out:
# Requirement already satisfied: ultranest in c:\users\pc\anaconda3\lib\site-packages\ultranest-4.3.1-py3.11-win-amd64.egg (4.3.1)
# Requirement already satisfied: numpy<2 in c:\users\pc\anaconda3\lib\site-packages (from ultranest) (1.24.3)
# Requirement already satisfied: cython in c:\users\pc\anaconda3\lib\site-packages (from ultranest) (3.0.10)
# Requirement already satisfied: matplotlib in c:\users\pc\anaconda3\lib\site-packages (from ultranest) (3.7.2)
# Requirement already satisfied: corner in c:\users\pc\anaconda3\lib\site-packages (from ultranest) (2.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pc\anaconda3\lib\site-packages (from matplotlib->ultranest) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\pc\anaconda3\lib\site-packages (from matplotlib->ultranest) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pc\anaconda3\lib\site-packages\fonttools-4.53.0-py3.11.egg (from matplotlib->ultranest) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\pc\anaconda3\lib\site-packages (from matplotlib->ultranest) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\pc\anaconda3\lib\site-packages (from matplotlib->ultranest) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\pc\anaconda3\lib\site-packages (from matplotlib->ultranest) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\pc\anaconda3\lib\site-packages (from matplotlib->ultranest) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pc\anaconda3\lib\site-packages (from matplotlib->ultranest) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\pc\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->ultranest) (1.16.0)
# DEPRECATION: Loading egg at c:\users\pc\anaconda3\lib\site-packages\fonttools-4.53.0-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# DEPRECATION: Loading egg at c:\users\pc\anaconda3\lib\site-packages\ultranest-4.3.1-py3.11-win-amd64.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..

# %%
try:
    import ultranest
    print("ultranest module imported successfully.")
except ImportError as e:
    print(f"Error importing ultranest: {e}")
# Out:
# Error importing ultranest: No module named 'ultranest.mlfriends'

# %%
# !python RUN_AGNfitter_multi.py
# Out:
# python: can't open file 'C:\\Users\\PC\\AGNfitter\\UltraNest\\RUN_AGNfitter_multi.py': [Errno 2] No such file or directory

# %%
# Step 1: Navigate to the AGNfitter directory
import os
os.chdir('C:\\Users\\PC\\AGNfitter')
print(f"Changed to directory: {os.getcwd()}")

# Step 2: Verify the contents of the directory
# !dir

# Step 3: Ensure ultranest and other modules are importable
import sys
sys.path.append(os.getcwd())

try:
    import ultranest
    import acor
    from functions import MCMC_AGNfitter, PLOTandWRITE_AGNfitter
    print("Modules imported successfully.")
except ImportError as e:
    print(f"Error importing modules: {e}")

# Step 4: Run the AGNfitter script with the settings file
settings_file = r'C:\Users\PC\AGNfitter\example\SETTINGS_AGNfitter.py'
# !python RUN_AGNfitter_multi.py {settings_file}
# Out:
# Changed to directory: C:\Users\PC\AGNfitter
#  Volume in drive C has no label.
#  Volume Serial Number is A2A0-BBAD
#
#  Directory of C:\Users\PC\AGNfitter
#
# 07/03/2024  10:42 PM    <DIR>          .
# 07/03/2024  10:40 PM    <DIR>          ..
# 07/03/2024  07:52 PM    <DIR>          -p
# 07/02/2024  03:38 PM               907 .gitignore
# 07/03/2024  07:26 PM    <DIR>          .ipynb_checkpoints
# 07/02/2024  03:38 PM               191 .readthedocs.yaml
# 07/02/2024  04:41 PM    <DIR>          acor
# 07/02/2024  03:38 PM             3,792 catalog_example.txt
# 07/02/2024  03:38 PM    <DIR>          data
# 07/02/2024  03:38 PM    <DIR>          docs
# 07/02/2024  03:38 PM                 0 error.log
# 07/02/2024  08:04 PM    <DIR>          example
# 07/03/2024  10:15 PM    <DIR>          functions
# 07/02/2024  03:38 PM             1,112 LICENSE
# 07/02/2024  03:38 PM    <DIR>          models
# 07/03/2024  10:16 PM    <DIR>          OUTPUT
# 07/02/2024  03:38 PM             5,616 README.md
# 07/02/2024  03:38 PM             1,069 readthedocs.yaml
# 07/03/2024  10:42 PM            14,266 RUN_AGNfitter_multi.py
# 07/03/2024  07:54 PM             5,573 SETTINGS_AGNfitter.py
# 07/03/2024  08:59 PM    <DIR>          UltraNest
# 07/03/2024  07:28 PM            20,455 Untitled.ipynb
#               10 File(s)         52,981 bytes
#               12 Dir(s)  924,965,588,992 bytes free
# Modules imported successfully.
#
#              XXXX
# ___________ XXX _________________________________________________
#             XX
#             X
#             X                       AGNfitter
#          __ X __                    ---------
#      /**\   |   /**\
# ... (*** =  o  = ***) ...........................................
#      \**/__ | __\**/
#             X              Fitting SEDs of AGN and Galaxies
#             X             in a MCMC Approach
#            xx              (Calistro Rivera et al. 2016)
#           xx
# _______ xxx______________________________________________________
#      xxxx
# Traceback (most recent call last):
#   File "C:\Users\PC\AGNfitter\RUN_AGNfitter_multi.py", line 283, in <module>
#     exec (compile(open(args.AGNfitterSettings).read(), args.AGNfitterSettings, 'exec'))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\PC\\AGNfitter\\example\\SETTINGS_AGNfitter.py'

# %%
# settings.py
AGNfitterSettings = {
    "output_folder": "results/",
    "input_file": r'C:\Users\PC\AGNfitter\data\catalog_example.txt',  
    "redshift_type": "spec",
    "n_walkers": 50,
    "n_iterations": 1000,
    "n_burn": 200,
    "models": {
        "big_blue_bump": "models/BBB.txt",
        "dust_torus": "models/TORUS.txt",
        "starburst": "models/SB.txt",
        "host_galaxy": "models/GALAXY.txt"
    },
    "filters": "filters/FILTERS.txt",
    "cosmology": {
        "H0": 70.0,
        "Omega_m": 0.3,
        "Omega_Lambda": 0.7
    }
}

# %%
# Step 1: Navigate to the AGNfitter directory
os.chdir('C:\\Users\\PC\\AGNfitter')
print(f"Changed to directory: {os.getcwd()}")

# Step 2: Run the AGNfitter script with the settings file
settings_file = r'C:\Users\PC\AGNfitter\example\SETTINGS_AGNfitter.py'
# !python RUN_AGNfitter_multi.py {settings_file}
# Out:
# Changed to directory: C:\Users\PC\AGNfitter
#
#              XXXX
# ___________ XXX _________________________________________________
#             XX
#             X
#             X                       AGNfitter
#          __ X __                    ---------
#      /**\   |   /**\
# ... (*** =  o  = ***) ...........................................
#      \**/__ | __\**/
#             X              Fitting SEDs of AGN and Galaxies
#             X             in a MCMC Approach
#            xx              (Calistro Rivera et al. 2016)
#           xx
# _______ xxx______________________________________________________
#      xxxx
# Traceback (most recent call last):
#   File "C:\Users\PC\AGNfitter\RUN_AGNfitter_multi.py", line 283, in <module>
#     exec (compile(open(args.AGNfitterSettings).read(), args.AGNfitterSettings, 'exec'))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\PC\\AGNfitter\\example\\SETTINGS_AGNfitter.py'

# %%
import os

# Check the current directory
print(os.getcwd())
# Out:
# C:\Users\PC\AGNfitter

# %%
# List the contents of the data directory
os.listdir(r'C:\Users\PC\AGNfitter\data')
# Out:
# ['brown2018_test.txt', 'catalog_example.txt']

# %%
# Update the settings file to reflect the correct path to the input file
AGNfitterSettings = {
    "output_folder": "results/",
    "input_file": r'C:\Users\PC\AGNfitter\data\catalog_example.txt',
    "redshift_type": "spec",
    "n_walkers": 50,
    "n_iterations": 1000,
    "n_burn": 200,
    "models": {
        "big_blue_bump": "models/BBB.txt",
        "dust_torus": "models/TORUS.txt",
        "starburst": "models/SB.txt",
        "host_galaxy": "models/GALAXY.txt"
    },
    "filters": "filters/FILTERS.txt",
    "cosmology": {
        "H0": 70.0,
        "Omega_m": 0.3,
        "Omega_Lambda": 0.7
    }
}

# %%
# Step 1: Navigate to the AGNfitter directory
os.chdir(r'C:\Users\PC\AGNfitter')
print(f"Changed to directory: {os.getcwd()}")
# Out:
# Changed to directory: C:\Users\PC\AGNfitter

# %%
# Step 2: Run the AGNfitter script with the settings file
settings_file = r'C:\Users\PC\AGNfitter\example\SETTINGS_AGNfitter.py' 
# !python RUN_AGNfitter_multi.py {SETTINGS_AGNfitter.py}
# Out:
#
#              XXXX
# ___________ XXX _________________________________________________
#             XX
#             X
#             X                       AGNfitter
#          __ X __                    ---------
#      /**\   |   /**\
# ... (*** =  o  = ***) ...........................................
#      \**/__ | __\**/
#             X              Fitting SEDs of AGN and Galaxies
#             X             in a MCMC Approach
#            xx              (Calistro Rivera et al. 2016)
#           xx
# _______ xxx______________________________________________________
#      xxxx
# Traceback (most recent call last):
#   File "C:\Users\PC\AGNfitter\RUN_AGNfitter_multi.py", line 283, in <module>
#     exec (compile(open(args.AGNfitterSettings).read(), args.AGNfitterSettings, 'exec'))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '{SETTINGS_AGNfitter.py}'

# %%
import os
import sys

# Step 1: Navigate to the AGNfitter directory
os.chdir('C:\\Users\\PC\\AGNfitter')
print(f"Changed to directory: {os.getcwd()}")

# Step 2: Verify the contents of the directory to ensure the settings file is there
print(os.listdir())

# Step 3: Ensure ultranest and other modules are importable
sys.path.append(os.getcwd())

try:
    import ultranest
    import acor
    from functions import MCMC_AGNfitter, PLOTandWRITE_AGNfitter
    print("Modules imported successfully.")
except ImportError as e:
    print(f"Error importing modules: {e}")

# Step 4: Define the path to the settings file
settings_file = 'SETTINGS_AGNfitter.py'  # Use the actual name of your settings file

# Verify the file path
print(f"Settings file path: {settings_file}")

# Step 5: Run the AGNfitter script with the settings file
# !python RUN_AGNfitter_multi.py {settings_file}
# Out:
# Changed to directory: C:\Users\PC\AGNfitter
# ['-p', '.git', '.gitignore', '.ipynb_checkpoints', '.readthedocs.yaml', 'acor', 'catalog_example.txt', 'data', 'docs', 'error.log', 'example', 'functions', 'LICENSE', 'models', 'OUTPUT', 'README.md', 'readthedocs.yaml', 'RUN_AGNfitter_multi.py', 'SETTINGS_AGNfitter.py', 'UltraNest', 'Untitled.ipynb']
# Modules imported successfully.
# Settings file path: SETTINGS_AGNfitter.py
#
#              XXXX
# ___________ XXX _________________________________________________
#             XX
#             X
#             X                       AGNfitter
#          __ X __                    ---------
#      /**\   |   /**\
# ... (*** =  o  = ***) ...........................................
#      \**/__ | __\**/
#             X              Fitting SEDs of AGN and Galaxies
#             X             in a MCMC Approach
#            xx              (Calistro Rivera et al. 2016)
#           xx
# _______ xxx______________________________________________________
#      xxxx
#
# Catalog settings:  {'path': 'C:\\Users\\PC\\AGNfitter\\', 'filename': 'C:\\Users\\PC\\AGNfitter\\catalog_example.txt', 'filetype': 'ASCII', 'name': 0, 'redshift': 1, 'freq/wl_list': [2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74, 77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137, 140, 143, 146], 'use_central_wavelength': True, 'freq/wl_format': 'wavelength', 'freq/wl_unit': Unit("micron"), 'flux_in_magAB': False, 'flux_unit': <Quantity 0.001 Jy>, 'flux_list': [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147], 'fluxerr_list': [4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70, 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 103, 106, 109, 112, 115, 118, 121, 124, 127, 130, 133, 136, 139, 142, 145, 148], 'err+10%flux_moreflex': False, 'ndflag_bool': False, 'ndflag_list': 'list', 'workingpath': 'C:\\Users\\PC\\AGNfitter\\', 'output_folder': 'C:\\Users\\PC\\AGNfitter\\OUTPUT/'}
# Filters settings:  {'dict_zarray': array([], dtype=float64), 'path': 'models/FILTERS/', 'filterset': 'example_46datapointa', '4XMM_EP5': [True, 48], '4XMM_EP4': [True, 47], '4XMM_EP3': [True, 46], '4XMM_EP2': [True, 45], 'RAD_1_4GHz': [True, 44], 'RAD_5GHz': [True, 43], 'RAD_15GHz': [True, 42], 'SPIRE500': [True, 41], 'SPIRE350': [True, 40], 'SPIRE250': [True, 39], 'PACS160': [True, 38], 'PACS100': [True, 37], 'PACS70': [True, 36], 'M1': [True, 35], 'WISE4': [True, 34], 'WISE3': [True, 33], 'IRAC4': [True, 32], 'IRAC3': [True, 31], 'WISE2': [True, 30], 'IRAC2': [True, 29], 'IRAC1': [True, 28], 'WISE1': [True, 27], 'Ks_2mass': [True, 26], 'H_2mass': [True, 25], 'J_2mass': [True, 24], 'y_PS1_good': [True, 23], 'SKY_z': [True, 22], 'z': [True, 21], 'z_PS1': [True, 20], 'SKY_i': [True, 19], 'i_PS1': [True, 18], 'i': [True, 17], 'SKY_r': [True, 16], 'r_PS1': [True, 15], 'r': [True, 14], 'SWIFT_V': [True, 13], 'SKY_g': [True, 12], 'g_PS1': [True, 11], 'g': [True, 10], 'SWIFT_B': [True, 9], 'SKY_v': [True, 8], 'u': [True, 7], 'SKY_u': [True, 6], 'SWIFT_U': [True, 5], 'SWIFT_W1': [True, 4], 'GALEX_2500': [True, 3], 'SWIFT_M2': [True, 2], 'SWIFT_W2': [True, 1], 'GALEX_1500': [True, 0], 'add_filters': False, 'add_filters_dict': {'names': [], 'filenames': [], 'freq/wl_format': [], 'freq/wl_unit': [], 'description': []}}
# Models settings:  {'path': 'models/', 'modelset': 'modelsv1', 'GALAXY': 'BC03_metal', 'STARBURST': 'S17', 'BBB': 'THB21', 'TORUS': 'SKIRTOR_1P', 'XRAYS': False, 'RADIO': False, 'Blazar': 'None', 'PRIOR_energy_balance': 'Flexible', 'PRIOR_AGNfraction': True, 'PRIOR_midIR_UV': False, 'PRIOR_galaxy_only': False, 'turn_on_AGN': True}
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Option of one single dictionary for a whole catalogue is deprecated. Running "independent, -i" option.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  0
# - Sourcename:  Mrk493
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  1
# - Sourcename:  Mrk876
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 2 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 3 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 4 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 5 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 6 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 7 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 8 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 9 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 10 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 11 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 12 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 13 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 14 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 15 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 16 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 17 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 18 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 19 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 20 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 21 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 22 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 23 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 24 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 25 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
# ...
# Error: Line index 100 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 101 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 102 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 103 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 104 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 105 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 106 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 107 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 108 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 109 is out of bounds for the data array with size 2
# ======= : =======
# Process finished.
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)

# %%
import os

# Check the current working directory
print(f"Current working directory: {os.getcwd()}")
# Out:
# Current working directory: C:\Users\PC\AGNfitter

# %%
print(os.listdir(r'C:\Users\PC\AGNfitter'))
# Out:
# ['-p', '.git', '.gitignore', '.ipynb_checkpoints', '.readthedocs.yaml', 'acor', 'catalog_example.txt', 'data', 'docs', 'error.log', 'example', 'functions', 'LICENSE', 'models', 'OUTPUT', 'README.md', 'readthedocs.yaml', 'RUN_AGNfitter_multi.py', 'SETTINGS_AGNfitter.py', 'UltraNest', 'Untitled.ipynb']

# %%
import os
import sys

# Step 1: Navigate to the AGNfitter directory
os.chdir(r'C:\Users\PC\AGNfitter')
print(f"Changed to directory: {os.getcwd()}")

# Step 2: Verify the contents of the directory to ensure the settings file is there
print(os.listdir())

# Step 3: Ensure ultranest and other modules are importable
sys.path.append(os.getcwd())

try:
    import ultranest
    import acor
    from functions import MCMC_AGNfitter, PLOTandWRITE_AGNfitter
    print("Modules imported successfully.")
except ImportError as e:
    print(f"Error importing modules: {e}")

# Step 4: Define the path to the settings file
settings_file = r'C:\Users\PC\AGNfitter\SETTINGS_AGNfitter.py'  # Ensure this is the correct path

# Verify the file path
print(f"Settings file path: {settings_file}")

# Step 5: Run the AGNfitter script with the settings file
# !python RUN_AGNfitter_multi.py {settings_file}
# Out:
# Changed to directory: C:\Users\PC\AGNfitter
# ['-p', '.git', '.gitignore', '.ipynb_checkpoints', '.readthedocs.yaml', 'acor', 'catalog_example.txt', 'data', 'docs', 'error.log', 'example', 'functions', 'LICENSE', 'models', 'OUTPUT', 'README.md', 'readthedocs.yaml', 'RUN_AGNfitter_multi.py', 'SETTINGS_AGNfitter.py', 'UltraNest', 'Untitled.ipynb']
# Modules imported successfully.
# Settings file path: C:\Users\PC\AGNfitter\SETTINGS_AGNfitter.py
#
#              XXXX
# ___________ XXX _________________________________________________
#             XX
#             X
#             X                       AGNfitter
#          __ X __                    ---------
#      /**\   |   /**\
# ... (*** =  o  = ***) ...........................................
#      \**/__ | __\**/
#             X              Fitting SEDs of AGN and Galaxies
#             X             in a MCMC Approach
#            xx              (Calistro Rivera et al. 2016)
#           xx
# _______ xxx______________________________________________________
#      xxxx
#
# Catalog settings:  {'path': 'C:\\Users\\PC\\AGNfitter\\', 'filename': 'C:\\Users\\PC\\AGNfitter\\catalog_example.txt', 'filetype': 'ASCII', 'name': 0, 'redshift': 1, 'freq/wl_list': [2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74, 77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137, 140, 143, 146], 'use_central_wavelength': True, 'freq/wl_format': 'wavelength', 'freq/wl_unit': Unit("micron"), 'flux_in_magAB': False, 'flux_unit': <Quantity 0.001 Jy>, 'flux_list': [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147], 'fluxerr_list': [4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70, 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 103, 106, 109, 112, 115, 118, 121, 124, 127, 130, 133, 136, 139, 142, 145, 148], 'err+10%flux_moreflex': False, 'ndflag_bool': False, 'ndflag_list': 'list', 'workingpath': 'C:\\Users\\PC\\AGNfitter\\', 'output_folder': 'C:\\Users\\PC\\AGNfitter\\OUTPUT/'}
# Filters settings:  {'dict_zarray': array([], dtype=float64), 'path': 'models/FILTERS/', 'filterset': 'example_46datapointa', '4XMM_EP5': [True, 48], '4XMM_EP4': [True, 47], '4XMM_EP3': [True, 46], '4XMM_EP2': [True, 45], 'RAD_1_4GHz': [True, 44], 'RAD_5GHz': [True, 43], 'RAD_15GHz': [True, 42], 'SPIRE500': [True, 41], 'SPIRE350': [True, 40], 'SPIRE250': [True, 39], 'PACS160': [True, 38], 'PACS100': [True, 37], 'PACS70': [True, 36], 'M1': [True, 35], 'WISE4': [True, 34], 'WISE3': [True, 33], 'IRAC4': [True, 32], 'IRAC3': [True, 31], 'WISE2': [True, 30], 'IRAC2': [True, 29], 'IRAC1': [True, 28], 'WISE1': [True, 27], 'Ks_2mass': [True, 26], 'H_2mass': [True, 25], 'J_2mass': [True, 24], 'y_PS1_good': [True, 23], 'SKY_z': [True, 22], 'z': [True, 21], 'z_PS1': [True, 20], 'SKY_i': [True, 19], 'i_PS1': [True, 18], 'i': [True, 17], 'SKY_r': [True, 16], 'r_PS1': [True, 15], 'r': [True, 14], 'SWIFT_V': [True, 13], 'SKY_g': [True, 12], 'g_PS1': [True, 11], 'g': [True, 10], 'SWIFT_B': [True, 9], 'SKY_v': [True, 8], 'u': [True, 7], 'SKY_u': [True, 6], 'SWIFT_U': [True, 5], 'SWIFT_W1': [True, 4], 'GALEX_2500': [True, 3], 'SWIFT_M2': [True, 2], 'SWIFT_W2': [True, 1], 'GALEX_1500': [True, 0], 'add_filters': False, 'add_filters_dict': {'names': [], 'filenames': [], 'freq/wl_format': [], 'freq/wl_unit': [], 'description': []}}
# Models settings:  {'path': 'models/', 'modelset': 'modelsv1', 'GALAXY': 'BC03_metal', 'STARBURST': 'S17', 'BBB': 'THB21', 'TORUS': 'SKIRTOR_1P', 'XRAYS': False, 'RADIO': False, 'Blazar': 'None', 'PRIOR_energy_balance': 'Flexible', 'PRIOR_AGNfraction': True, 'PRIOR_midIR_UV': False, 'PRIOR_galaxy_only': False, 'turn_on_AGN': True}
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Option of one single dictionary for a whole catalogue is deprecated. Running "independent, -i" option.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  0
# - Sourcename:  Mrk493
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  1
# - Sourcename:  Mrk876
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 2 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 3 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 4 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 5 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 6 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 7 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 8 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 9 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 10 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 11 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 12 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 13 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 14 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 15 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 16 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 17 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 18 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 19 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 20 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 21 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 22 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 23 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 24 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 25 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
# ...
# Error: Line index 100 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 101 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 102 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 103 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 104 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 105 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 106 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 107 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 108 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 109 is out of bounds for the data array with size 2
# ======= : =======
# Process finished.
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)

# %%
import os

# Check if the file exists at the specified path
catalog_path = r'C:\Users\PC\AGNfitter\data\catalog_example.txt'
file_exists = os.path.isfile(catalog_path)
print(f"File exists: {file_exists}")
# Out:
# File exists: True

# %%
# Print the contents of the settings file to ensure it is correctly formatted
settings_file_path = r'C:\Users\PC\AGNfitter\SETTINGS_AGNfitter.py'
with open(settings_file_path, 'r') as file:
    settings_content = file.read()
    print(settings_content)
# Out:
# def CATALOG_settings():
#     cat = dict()
#     cat['path'] = 'C:\\Users\\PC\\AGNfitter\\' #path to the AGNfitter code
#     cat['filename'] = cat['path'] + 'catalog_example.txt'
#     cat['filetype'] = 'ASCII'
#     cat['name'] = 0
#     cat['redshift'] = 1
#     cat['freq/wl_list'] = np.arange(2, 147, 3).tolist()
#     cat['use_central_wavelength'] = True
#     cat['freq/wl_format'] = 'wavelength'
#     cat['freq/wl_unit'] = u.micron
#     cat['flux_in_magAB'] = False
#     cat['flux_unit'] = u.Jy * 1e-3
#     cat['flux_list'] = np.arange(3, 148, 3).tolist()
#     cat['fluxerr_list'] = np.arange(4, 149, 3).tolist()
#     cat['err+10%flux_moreflex'] = False
#     cat['ndflag_bool'] = False
#     cat['ndflag_list'] = 'list'
#     cat['workingpath'] = cat['path']
#     cat['output_folder'] = cat['workingpath'] + 'OUTPUT/'
#     print("Catalog settings: ", cat) # Debugging line
#     return cat
#
# def FILTERS_settings():
#     filters = dict()
#     filters['dict_zarray'] = np.array([])
#     filters['path'] = 'models/FILTERS/'
#     filters['filterset'] = 'example_46datapointa'
#     filters['4XMM_EP5'] = [True, 48]
#     filters['4XMM_EP4'] = [True, 47]
#     filters['4XMM_EP3'] = [True, 46]
#     filters['4XMM_EP2'] = [True, 45]
#     filters['RAD_1_4GHz'] = [True, 44]
#     filters['RAD_5GHz'] = [True, 43]
#     filters['RAD_15GHz'] = [True, 42]
#     filters['SPIRE500'] = [True, 41]
#     filters['SPIRE350'] = [True, 40]
#     filters['SPIRE250'] = [True, 39]
#     filters['PACS160'] = [True, 38]
#     filters['PACS100'] = [True, 37]
#     filters['PACS70'] = [True, 36]
#     filters['M1'] = [True, 35]
#     filters['WISE4'] = [True, 34]
#     filters['WISE3'] = [True, 33]
#     filters['IRAC4'] = [True, 32]
#     filters['IRAC3'] = [True, 31]
#     filters['WISE2'] = [True, 30]
#     filters['IRAC2'] = [True, 29]
#     filters['IRAC1'] = [True, 28]
#     filters['WISE1'] = [True, 27]
#     filters['Ks_2mass'] = [True, 26]
#     filters['H_2mass'] = [True, 25]
#     filters['J_2mass'] = [True, 24]
#     filters['y_PS1_good'] = [True, 23]
#     filters['SKY_z'] = [True, 22]
#     filters['z'] = [True, 21]
#     filters['z_PS1'] = [True, 20]
#     filters['SKY_i'] = [True, 19]
#     filters['i_PS1'] = [True, 18]
#     filters['i'] = [True, 17]
#     filters['SKY_r'] = [True, 16]
#     filters['r_PS1'] = [True, 15]
#     filters['r'] = [True, 14]
#     filters['SWIFT_V'] = [True, 13]
#     filters['SKY_g'] = [True, 12]
#     filters['g_PS1'] = [True, 11]
#     filters['g'] = [True, 10]
#     filters['SWIFT_B'] = [True, 9]
#     filters['SKY_v'] = [True, 8]
#     filters['u'] = [True, 7]
#     filters['SKY_u'] = [True, 6]
#     filters['SWIFT_U'] = [True, 5]
#     filters['SWIFT_W1'] = [True, 4]
#     filters['GALEX_2500'] = [True, 3]
#     filters['SWIFT_M2'] = [True, 2]
#     filters['SWIFT_W2'] = [True, 1]
#     filters['GALEX_1500'] = [True, 0]
#     filters['add_filters'] = False
#     ADDfilters = dict()
#     ADDfilters['names'] = []
#     ADDfilters['filenames'] = []
#     ADDfilters['freq/wl_format'] = []
#     ADDfilters['freq/wl_unit'] = []
#     ADDfilters['description'] = []
#     filters['add_filters_dict'] = ADDfilters
#     print("Filters settings: ", filters) # Debugging line
#     return filters
#
# def MODELS_settings():
#     models = dict()
#     models['path'] = 'models/'
#     models['modelset'] = 'modelsv1'
#     models['GALAXY'] = 'BC03_metal'
#     models['STARBURST'] = 'S17'
#     models['BBB'] = 'THB21'
#     models['TORUS'] = 'SKIRTOR_1P'
#     models['XRAYS'] = False
#     models['RADIO'] = False
#     models['Blazar'] = 'None'
#     models['PRIOR_energy_balance'] = 'Flexible'
#     models['PRIOR_AGNfraction'] = True
#     models['PRIOR_midIR_UV'] = False
#     models['PRIOR_galaxy_only'] = False
#     models['turn_on_AGN'] = True
#     print("Models settings: ", models) # Debugging line
#     return models
#
# def MCMC_settings():
#     mc = dict()
#     mc['sampling_algorithm'] = 'ultranest'
#     mc['Nwalkers'] = 100
#     mc['Nburnsets'] = 2
#     mc['Nburn'] = 12000
#     mc['Nmcmc'] = 25000
#     mc['iprint'] = 1000
#     mc['direction_generation'] = 'de-mix'
#     mc['live_points'] = 400
#     mc['min_ess'] = 400
#     mc['num_loops'] = 0
#     print("MCMC settings: ", mc) # Debugging line
#     return mc
#
# def OUTPUT_settings():
#     out = dict()
#     out['plot_format'] = 'pdf'
#     out['band_indicators'] = True
#     out['realizations_format'] = 'shaded'
#     out['plot_tracesburn-in'] = False
#     out['plot_tracesmcmc'] = True
#     out['Nsample'] = 1000
#     out['Nthinning'] = 10
#     out['writepar_meanwitherrors'] = True
#     out['plot_posteriortriangle'] = True
#     out['calc_intlum'] = True
#     out['save_posterior_luminosities'] = False
#     out['save_posteriors'] = True
#     out['realizations2int'] = 100
#     out['plot_posteriortrianglewithluminosities'] = False
#     out['intlum_models'] = ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb']
#     out['intlum_freqranges_unit'] = u.micron
#     out['intlum_freqranges'] = np.array([[8., 1000.], [0.1, 1.], [0.1, 1.], [0.1, 1.], [0.1, 1.], [1., 30.], [0.1, 30], [8., 1000.], [0.4, 0.5], [0.4, 0.5], [0.4, 0.5], [6, 6], [1., 30.]])
#     out['intlum_names'] = ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)']
#     out['realizations2plot'] = 10
#     out['plot_best_fit'] = True
#     out['plot_median_fit'] = False
#     out['plot_residuals'] = True
#     out['saveSEDresiduals'] = True
#     out['plotSEDrealizations'] = True
#     out['saveSEDrealizations'] = True
#     print("Output settings: ", out) # Debugging line
#     return out

# %%
# Example content of SETTINGS_AGNfitter.py
AGNfitterSettings = {
    "output_folder": "results/",
    "input_file": r'C:\Users\PC\AGNfitter\catalog_example.txt',  # Ensure this path is correct
    "redshift_type": "spec",
    "n_walkers": 50,
    "n_iterations": 1000,
    "n_burn": 200,
    "models": {
        "big_blue_bump": "models/BBB.txt",
        "dust_torus": "models/TORUS.txt",
        "starburst": "models/SB.txt",
        "host_galaxy": "models/GALAXY.txt"
    },
    "filters": "filters/FILTERS.txt",
    "cosmology": {
        "H0": 70.0,
        "Omega_m": 0.3,
        "Omega_Lambda": 0.7
    }
}

# %%
import os
import sys

# Step 1: Navigate to the AGNfitter directory
os.chdir(r'C:\Users\PC\AGNfitter')
print(f"Changed to directory: {os.getcwd()}")

# Step 2: Verify the contents of the directory to ensure the settings file is there
print(os.listdir())

# Step 3: Ensure ultranest and other modules are importable
sys.path.append(os.getcwd())

try:
    import ultranest
    import acor
    from functions import MCMC_AGNfitter, PLOTandWRITE_AGNfitter
    print("Modules imported successfully.")
except ImportError as e:
    print(f"Error importing modules: {e}")

# Step 4: Define the path to the settings file
settings_file = 'SETTINGS_AGNfitter.py'  # Use the actual name of your settings file

# Verify the file path
print(f"Settings file path: {settings_file}")

# Step 5: Run the AGNfitter script with the settings file
# !python RUN_AGNfitter_multi.py {settings_file}
# Out:
# Changed to directory: C:\Users\PC\AGNfitter
# ['-p', '.git', '.gitignore', '.ipynb_checkpoints', '.readthedocs.yaml', 'acor', 'catalog_example.txt', 'data', 'docs', 'error.log', 'example', 'functions', 'LICENSE', 'models', 'OUTPUT', 'README.md', 'readthedocs.yaml', 'RUN_AGNfitter_multi.py', 'SETTINGS_AGNfitter.py', 'UltraNest', 'Untitled.ipynb']
# Modules imported successfully.
# Settings file path: SETTINGS_AGNfitter.py
#
#              XXXX
# ___________ XXX _________________________________________________
#             XX
#             X
#             X                       AGNfitter
#          __ X __                    ---------
#      /**\   |   /**\
# ... (*** =  o  = ***) ...........................................
#      \**/__ | __\**/
#             X              Fitting SEDs of AGN and Galaxies
#             X             in a MCMC Approach
#            xx              (Calistro Rivera et al. 2016)
#           xx
# _______ xxx______________________________________________________
#      xxxx
#
# Catalog settings:  {'path': 'C:\\Users\\PC\\AGNfitter\\', 'filename': 'C:\\Users\\PC\\AGNfitter\\catalog_example.txt', 'filetype': 'ASCII', 'name': 0, 'redshift': 1, 'freq/wl_list': [2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74, 77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137, 140, 143, 146], 'use_central_wavelength': True, 'freq/wl_format': 'wavelength', 'freq/wl_unit': Unit("micron"), 'flux_in_magAB': False, 'flux_unit': <Quantity 0.001 Jy>, 'flux_list': [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147], 'fluxerr_list': [4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70, 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 103, 106, 109, 112, 115, 118, 121, 124, 127, 130, 133, 136, 139, 142, 145, 148], 'err+10%flux_moreflex': False, 'ndflag_bool': False, 'ndflag_list': 'list', 'workingpath': 'C:\\Users\\PC\\AGNfitter\\', 'output_folder': 'C:\\Users\\PC\\AGNfitter\\OUTPUT/'}
# Filters settings:  {'dict_zarray': array([], dtype=float64), 'path': 'models/FILTERS/', 'filterset': 'example_46datapointa', '4XMM_EP5': [True, 48], '4XMM_EP4': [True, 47], '4XMM_EP3': [True, 46], '4XMM_EP2': [True, 45], 'RAD_1_4GHz': [True, 44], 'RAD_5GHz': [True, 43], 'RAD_15GHz': [True, 42], 'SPIRE500': [True, 41], 'SPIRE350': [True, 40], 'SPIRE250': [True, 39], 'PACS160': [True, 38], 'PACS100': [True, 37], 'PACS70': [True, 36], 'M1': [True, 35], 'WISE4': [True, 34], 'WISE3': [True, 33], 'IRAC4': [True, 32], 'IRAC3': [True, 31], 'WISE2': [True, 30], 'IRAC2': [True, 29], 'IRAC1': [True, 28], 'WISE1': [True, 27], 'Ks_2mass': [True, 26], 'H_2mass': [True, 25], 'J_2mass': [True, 24], 'y_PS1_good': [True, 23], 'SKY_z': [True, 22], 'z': [True, 21], 'z_PS1': [True, 20], 'SKY_i': [True, 19], 'i_PS1': [True, 18], 'i': [True, 17], 'SKY_r': [True, 16], 'r_PS1': [True, 15], 'r': [True, 14], 'SWIFT_V': [True, 13], 'SKY_g': [True, 12], 'g_PS1': [True, 11], 'g': [True, 10], 'SWIFT_B': [True, 9], 'SKY_v': [True, 8], 'u': [True, 7], 'SKY_u': [True, 6], 'SWIFT_U': [True, 5], 'SWIFT_W1': [True, 4], 'GALEX_2500': [True, 3], 'SWIFT_M2': [True, 2], 'SWIFT_W2': [True, 1], 'GALEX_1500': [True, 0], 'add_filters': False, 'add_filters_dict': {'names': [], 'filenames': [], 'freq/wl_format': [], 'freq/wl_unit': [], 'description': []}}
# Models settings:  {'path': 'models/', 'modelset': 'modelsv1', 'GALAXY': 'BC03_metal', 'STARBURST': 'S17', 'BBB': 'THB21', 'TORUS': 'SKIRTOR_1P', 'XRAYS': False, 'RADIO': False, 'Blazar': 'None', 'PRIOR_energy_balance': 'Flexible', 'PRIOR_AGNfraction': True, 'PRIOR_midIR_UV': False, 'PRIOR_galaxy_only': False, 'turn_on_AGN': True}
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Option of one single dictionary for a whole catalogue is deprecated. Running "independent, -i" option.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  0
# - Sourcename:  Mrk493
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  1
# - Sourcename:  Mrk876
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 2 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 3 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 4 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 5 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 6 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 7 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 8 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 9 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 10 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 11 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 12 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 13 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 14 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 15 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 16 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 17 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 18 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 19 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 20 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 21 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 22 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 23 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 24 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 25 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
# ...
# Error: Line index 100 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 101 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 102 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 103 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 104 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 105 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 106 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 107 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 108 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 109 is out of bounds for the data array with size 2
# ======= : =======
# Process finished.
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)

# %%
# List the contents of the AGNfitter directory
print(os.listdir(r'C:\Users\PC\AGNfitter'))

# List the contents of the data directory within AGNfitter
print(os.listdir(r'C:\Users\PC\AGNfitter'))
# Out:
# ['-p', '.git', '.gitignore', '.ipynb_checkpoints', '.readthedocs.yaml', 'acor', 'catalog_example.txt', 'data', 'docs', 'error.log', 'example', 'functions', 'LICENSE', 'models', 'OUTPUT', 'README.md', 'readthedocs.yaml', 'RUN_AGNfitter_multi.py', 'SETTINGS_AGNfitter.py', 'UltraNest', 'Untitled.ipynb']
# ['-p', '.git', '.gitignore', '.ipynb_checkpoints', '.readthedocs.yaml', 'acor', 'catalog_example.txt', 'data', 'docs', 'error.log', 'example', 'functions', 'LICENSE', 'models', 'OUTPUT', 'README.md', 'readthedocs.yaml', 'RUN_AGNfitter_multi.py', 'SETTINGS_AGNfitter.py', 'UltraNest', 'Untitled.ipynb']

# %%
# Check if the file exists at the specified path
catalog_path = r'C:\Users\PC\AGNfitter\catalog_example.txt'
file_exists = os.path.isfile(catalog_path)
print(f"File exists at {catalog_path}: {file_exists}")
# Out:
# File exists at C:\Users\PC\AGNfitter\catalog_example.txt: True

# %%
# Print the contents of the settings file to ensure it is correctly formatted
settings_file_path = 'C:\\Users\\PC\\AGNfitter\\SETTINGS_AGNfitter.py'
with open(settings_file_path, 'r') as file:
    settings_content = file.read()
    print(settings_content)
# Out:
# def CATALOG_settings():
#     cat = dict()
#     cat['path'] = 'C:\\Users\\PC\\AGNfitter\\' #path to the AGNfitter code
#     cat['filename'] = cat['path'] + 'catalog_example.txt'
#     cat['filetype'] = 'ASCII'
#     cat['name'] = 0
#     cat['redshift'] = 1
#     cat['freq/wl_list'] = np.arange(2, 147, 3).tolist()
#     cat['use_central_wavelength'] = True
#     cat['freq/wl_format'] = 'wavelength'
#     cat['freq/wl_unit'] = u.micron
#     cat['flux_in_magAB'] = False
#     cat['flux_unit'] = u.Jy * 1e-3
#     cat['flux_list'] = np.arange(3, 148, 3).tolist()
#     cat['fluxerr_list'] = np.arange(4, 149, 3).tolist()
#     cat['err+10%flux_moreflex'] = False
#     cat['ndflag_bool'] = False
#     cat['ndflag_list'] = 'list'
#     cat['workingpath'] = cat['path']
#     cat['output_folder'] = cat['workingpath'] + 'OUTPUT/'
#     print("Catalog settings: ", cat) # Debugging line
#     return cat
#
# def FILTERS_settings():
#     filters = dict()
#     filters['dict_zarray'] = np.array([])
#     filters['path'] = 'models/FILTERS/'
#     filters['filterset'] = 'example_46datapointa'
#     filters['4XMM_EP5'] = [True, 48]
#     filters['4XMM_EP4'] = [True, 47]
#     filters['4XMM_EP3'] = [True, 46]
#     filters['4XMM_EP2'] = [True, 45]
#     filters['RAD_1_4GHz'] = [True, 44]
#     filters['RAD_5GHz'] = [True, 43]
#     filters['RAD_15GHz'] = [True, 42]
#     filters['SPIRE500'] = [True, 41]
#     filters['SPIRE350'] = [True, 40]
#     filters['SPIRE250'] = [True, 39]
#     filters['PACS160'] = [True, 38]
#     filters['PACS100'] = [True, 37]
#     filters['PACS70'] = [True, 36]
#     filters['M1'] = [True, 35]
#     filters['WISE4'] = [True, 34]
#     filters['WISE3'] = [True, 33]
#     filters['IRAC4'] = [True, 32]
#     filters['IRAC3'] = [True, 31]
#     filters['WISE2'] = [True, 30]
#     filters['IRAC2'] = [True, 29]
#     filters['IRAC1'] = [True, 28]
#     filters['WISE1'] = [True, 27]
#     filters['Ks_2mass'] = [True, 26]
#     filters['H_2mass'] = [True, 25]
#     filters['J_2mass'] = [True, 24]
#     filters['y_PS1_good'] = [True, 23]
#     filters['SKY_z'] = [True, 22]
#     filters['z'] = [True, 21]
#     filters['z_PS1'] = [True, 20]
#     filters['SKY_i'] = [True, 19]
#     filters['i_PS1'] = [True, 18]
#     filters['i'] = [True, 17]
#     filters['SKY_r'] = [True, 16]
#     filters['r_PS1'] = [True, 15]
#     filters['r'] = [True, 14]
#     filters['SWIFT_V'] = [True, 13]
#     filters['SKY_g'] = [True, 12]
#     filters['g_PS1'] = [True, 11]
#     filters['g'] = [True, 10]
#     filters['SWIFT_B'] = [True, 9]
#     filters['SKY_v'] = [True, 8]
#     filters['u'] = [True, 7]
#     filters['SKY_u'] = [True, 6]
#     filters['SWIFT_U'] = [True, 5]
#     filters['SWIFT_W1'] = [True, 4]
#     filters['GALEX_2500'] = [True, 3]
#     filters['SWIFT_M2'] = [True, 2]
#     filters['SWIFT_W2'] = [True, 1]
#     filters['GALEX_1500'] = [True, 0]
#     filters['add_filters'] = False
#     ADDfilters = dict()
#     ADDfilters['names'] = []
#     ADDfilters['filenames'] = []
#     ADDfilters['freq/wl_format'] = []
#     ADDfilters['freq/wl_unit'] = []
#     ADDfilters['description'] = []
#     filters['add_filters_dict'] = ADDfilters
#     print("Filters settings: ", filters) # Debugging line
#     return filters
#
# def MODELS_settings():
#     models = dict()
#     models['path'] = 'models/'
#     models['modelset'] = 'modelsv1'
#     models['GALAXY'] = 'BC03_metal'
#     models['STARBURST'] = 'S17'
#     models['BBB'] = 'THB21'
#     models['TORUS'] = 'SKIRTOR_1P'
#     models['XRAYS'] = False
#     models['RADIO'] = False
#     models['Blazar'] = 'None'
#     models['PRIOR_energy_balance'] = 'Flexible'
#     models['PRIOR_AGNfraction'] = True
#     models['PRIOR_midIR_UV'] = False
#     models['PRIOR_galaxy_only'] = False
#     models['turn_on_AGN'] = True
#     print("Models settings: ", models) # Debugging line
#     return models
#
# def MCMC_settings():
#     mc = dict()
#     mc['sampling_algorithm'] = 'ultranest'
#     mc['Nwalkers'] = 100
#     mc['Nburnsets'] = 2
#     mc['Nburn'] = 12000
#     mc['Nmcmc'] = 25000
#     mc['iprint'] = 1000
#     mc['direction_generation'] = 'de-mix'
#     mc['live_points'] = 400
#     mc['min_ess'] = 400
#     mc['num_loops'] = 0
#     print("MCMC settings: ", mc) # Debugging line
#     return mc
#
# def OUTPUT_settings():
#     out = dict()
#     out['plot_format'] = 'pdf'
#     out['band_indicators'] = True
#     out['realizations_format'] = 'shaded'
#     out['plot_tracesburn-in'] = False
#     out['plot_tracesmcmc'] = True
#     out['Nsample'] = 1000
#     out['Nthinning'] = 10
#     out['writepar_meanwitherrors'] = True
#     out['plot_posteriortriangle'] = True
#     out['calc_intlum'] = True
#     out['save_posterior_luminosities'] = False
#     out['save_posteriors'] = True
#     out['realizations2int'] = 100
#     out['plot_posteriortrianglewithluminosities'] = False
#     out['intlum_models'] = ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb']
#     out['intlum_freqranges_unit'] = u.micron
#     out['intlum_freqranges'] = np.array([[8., 1000.], [0.1, 1.], [0.1, 1.], [0.1, 1.], [0.1, 1.], [1., 30.], [0.1, 30], [8., 1000.], [0.4, 0.5], [0.4, 0.5], [0.4, 0.5], [6, 6], [1., 30.]])
#     out['intlum_names'] = ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)']
#     out['realizations2plot'] = 10
#     out['plot_best_fit'] = True
#     out['plot_median_fit'] = False
#     out['plot_residuals'] = True
#     out['saveSEDresiduals'] = True
#     out['plotSEDrealizations'] = True
#     out['saveSEDrealizations'] = True
#     print("Output settings: ", out) # Debugging line
#     return out

# %%
# Example content of SETTINGS_AGNfitter.py
AGNfitterSettings = {
    "output_folder": "results/",
    "input_file": "C:\\Users\\PC\\AGNfitter\\catalog_example.txt",  # Updated path
    "redshift_type": "spec",
    "n_walkers": 50,
    "n_iterations": 1000,
    "n_burn": 200,
    "models": {
        "big_blue_bump": "models/BBB.txt",
        "dust_torus": "models/TORUS.txt",
        "starburst": "models/SB.txt",
        "host_galaxy": "models/GALAXY.txt"
    },
    "filters": "filters/FILTERS.txt",
    "cosmology": {
        "H0": 70.0,
        "Omega_m": 0.3,
        "Omega_Lambda": 0.7
    }
}

# %%
import os

# Check if the file exists at the specified path
catalog_path = 'C:\\Users\\PC\\AGNfitter\\catalog_example.txt'
file_exists = os.path.isfile(catalog_path)
print(f"File exists at {catalog_path}: {file_exists}")
# Out:
# File exists at C:\Users\PC\AGNfitter\catalog_example.txt: True

# %%
import os
import sys

# Step 1: Navigate to the AGNfitter directory
os.chdir('C:\\Users\\PC\\AGNfitter')
print(f"Changed to directory: {os.getcwd()}")

# Step 2: Verify the contents of the directory to ensure the settings file is there
print(os.listdir())

# Step 3: Ensure ultranest and other modules are importable
sys.path.append(os.getcwd())

try:
    import ultranest
    import acor
    from functions import MCMC_AGNfitter, PLOTandWRITE_AGNfitter
    print("Modules imported successfully.")
except ImportError as e:
    print(f"Error importing modules: {e}")

# Step 4: Define the path to the settings file
settings_file = 'SETTINGS_AGNfitter.py'  # Use the actual name of your settings file

# Verify the file path
print(f"Settings file path: {settings_file}")

# Step 5: Run the AGNfitter script with the settings file
# !python RUN_AGNfitter_multi.py {settings_file}
# Out:
# Changed to directory: C:\Users\PC\AGNfitter
# ['-p', '.git', '.gitignore', '.ipynb_checkpoints', '.readthedocs.yaml', 'acor', 'catalog_example.txt', 'data', 'docs', 'error.log', 'example', 'functions', 'LICENSE', 'models', 'OUTPUT', 'README.md', 'readthedocs.yaml', 'RUN_AGNfitter_multi.py', 'SETTINGS_AGNfitter.py', 'UltraNest', 'Untitled.ipynb']
# Modules imported successfully.
# Settings file path: SETTINGS_AGNfitter.py
#
#              XXXX
# ___________ XXX _________________________________________________
#             XX
#             X
#             X                       AGNfitter
#          __ X __                    ---------
#      /**\   |   /**\
# ... (*** =  o  = ***) ...........................................
#      \**/__ | __\**/
#             X              Fitting SEDs of AGN and Galaxies
#             X             in a MCMC Approach
#            xx              (Calistro Rivera et al. 2016)
#           xx
# _______ xxx______________________________________________________
#      xxxx
#
# Catalog settings:  {'path': 'C:\\Users\\PC\\AGNfitter\\', 'filename': 'C:\\Users\\PC\\AGNfitter\\catalog_example.txt', 'filetype': 'ASCII', 'name': 0, 'redshift': 1, 'freq/wl_list': [2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74, 77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137, 140, 143, 146], 'use_central_wavelength': True, 'freq/wl_format': 'wavelength', 'freq/wl_unit': Unit("micron"), 'flux_in_magAB': False, 'flux_unit': <Quantity 0.001 Jy>, 'flux_list': [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147], 'fluxerr_list': [4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70, 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 103, 106, 109, 112, 115, 118, 121, 124, 127, 130, 133, 136, 139, 142, 145, 148], 'err+10%flux_moreflex': False, 'ndflag_bool': False, 'ndflag_list': 'list', 'workingpath': 'C:\\Users\\PC\\AGNfitter\\', 'output_folder': 'C:\\Users\\PC\\AGNfitter\\OUTPUT/'}
# Filters settings:  {'dict_zarray': array([], dtype=float64), 'path': 'models/FILTERS/', 'filterset': 'example_46datapointa', '4XMM_EP5': [True, 48], '4XMM_EP4': [True, 47], '4XMM_EP3': [True, 46], '4XMM_EP2': [True, 45], 'RAD_1_4GHz': [True, 44], 'RAD_5GHz': [True, 43], 'RAD_15GHz': [True, 42], 'SPIRE500': [True, 41], 'SPIRE350': [True, 40], 'SPIRE250': [True, 39], 'PACS160': [True, 38], 'PACS100': [True, 37], 'PACS70': [True, 36], 'M1': [True, 35], 'WISE4': [True, 34], 'WISE3': [True, 33], 'IRAC4': [True, 32], 'IRAC3': [True, 31], 'WISE2': [True, 30], 'IRAC2': [True, 29], 'IRAC1': [True, 28], 'WISE1': [True, 27], 'Ks_2mass': [True, 26], 'H_2mass': [True, 25], 'J_2mass': [True, 24], 'y_PS1_good': [True, 23], 'SKY_z': [True, 22], 'z': [True, 21], 'z_PS1': [True, 20], 'SKY_i': [True, 19], 'i_PS1': [True, 18], 'i': [True, 17], 'SKY_r': [True, 16], 'r_PS1': [True, 15], 'r': [True, 14], 'SWIFT_V': [True, 13], 'SKY_g': [True, 12], 'g_PS1': [True, 11], 'g': [True, 10], 'SWIFT_B': [True, 9], 'SKY_v': [True, 8], 'u': [True, 7], 'SKY_u': [True, 6], 'SWIFT_U': [True, 5], 'SWIFT_W1': [True, 4], 'GALEX_2500': [True, 3], 'SWIFT_M2': [True, 2], 'SWIFT_W2': [True, 1], 'GALEX_1500': [True, 0], 'add_filters': False, 'add_filters_dict': {'names': [], 'filenames': [], 'freq/wl_format': [], 'freq/wl_unit': [], 'description': []}}
# Models settings:  {'path': 'models/', 'modelset': 'modelsv1', 'GALAXY': 'BC03_metal', 'STARBURST': 'S17', 'BBB': 'THB21', 'TORUS': 'SKIRTOR_1P', 'XRAYS': False, 'RADIO': False, 'Blazar': 'None', 'PRIOR_energy_balance': 'Flexible', 'PRIOR_AGNfraction': True, 'PRIOR_midIR_UV': False, 'PRIOR_galaxy_only': False, 'turn_on_AGN': True}
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Option of one single dictionary for a whole catalogue is deprecated. Running "independent, -i" option.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  0
# - Sourcename:  Mrk493
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  1
# - Sourcename:  Mrk876
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 2 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 3 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 4 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 5 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 6 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 7 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 8 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 9 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 10 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 11 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 12 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 13 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 14 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 15 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 16 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 17 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 18 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 19 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 20 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 21 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 22 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 23 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 24 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 25 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
# ...
# Error: Line index 100 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 101 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 102 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 103 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 104 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 105 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 106 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 107 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 108 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 109 is out of bounds for the data array with size 2
# ======= : =======
# Process finished.
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)

# %%
# !python RUN_AGNfitter_multi.py {settings_file}
# Out:
#
#              XXXX
# ___________ XXX _________________________________________________
#             XX
#             X
#             X                       AGNfitter
#          __ X __                    ---------
#      /**\   |   /**\
# ... (*** =  o  = ***) ...........................................
#      \**/__ | __\**/
#             X              Fitting SEDs of AGN and Galaxies
#             X             in a MCMC Approach
#            xx              (Calistro Rivera et al. 2016)
#           xx
# _______ xxx______________________________________________________
#      xxxx
#
# Catalog settings:  {'path': 'C:\\Users\\PC\\AGNfitter\\', 'filename': 'C:\\Users\\PC\\AGNfitter\\catalog_example.txt', 'filetype': 'ASCII', 'name': 0, 'redshift': 1, 'freq/wl_list': [2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74, 77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137, 140, 143, 146], 'use_central_wavelength': True, 'freq/wl_format': 'wavelength', 'freq/wl_unit': Unit("micron"), 'flux_in_magAB': False, 'flux_unit': <Quantity 0.001 Jy>, 'flux_list': [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147], 'fluxerr_list': [4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70, 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 103, 106, 109, 112, 115, 118, 121, 124, 127, 130, 133, 136, 139, 142, 145, 148], 'err+10%flux_moreflex': False, 'ndflag_bool': False, 'ndflag_list': 'list', 'workingpath': 'C:\\Users\\PC\\AGNfitter\\', 'output_folder': 'C:\\Users\\PC\\AGNfitter\\OUTPUT/'}
# Filters settings:  {'dict_zarray': array([], dtype=float64), 'path': 'models/FILTERS/', 'filterset': 'example_46datapointa', '4XMM_EP5': [True, 48], '4XMM_EP4': [True, 47], '4XMM_EP3': [True, 46], '4XMM_EP2': [True, 45], 'RAD_1_4GHz': [True, 44], 'RAD_5GHz': [True, 43], 'RAD_15GHz': [True, 42], 'SPIRE500': [True, 41], 'SPIRE350': [True, 40], 'SPIRE250': [True, 39], 'PACS160': [True, 38], 'PACS100': [True, 37], 'PACS70': [True, 36], 'M1': [True, 35], 'WISE4': [True, 34], 'WISE3': [True, 33], 'IRAC4': [True, 32], 'IRAC3': [True, 31], 'WISE2': [True, 30], 'IRAC2': [True, 29], 'IRAC1': [True, 28], 'WISE1': [True, 27], 'Ks_2mass': [True, 26], 'H_2mass': [True, 25], 'J_2mass': [True, 24], 'y_PS1_good': [True, 23], 'SKY_z': [True, 22], 'z': [True, 21], 'z_PS1': [True, 20], 'SKY_i': [True, 19], 'i_PS1': [True, 18], 'i': [True, 17], 'SKY_r': [True, 16], 'r_PS1': [True, 15], 'r': [True, 14], 'SWIFT_V': [True, 13], 'SKY_g': [True, 12], 'g_PS1': [True, 11], 'g': [True, 10], 'SWIFT_B': [True, 9], 'SKY_v': [True, 8], 'u': [True, 7], 'SKY_u': [True, 6], 'SWIFT_U': [True, 5], 'SWIFT_W1': [True, 4], 'GALEX_2500': [True, 3], 'SWIFT_M2': [True, 2], 'SWIFT_W2': [True, 1], 'GALEX_1500': [True, 0], 'add_filters': False, 'add_filters_dict': {'names': [], 'filenames': [], 'freq/wl_format': [], 'freq/wl_unit': [], 'description': []}}
# Models settings:  {'path': 'models/', 'modelset': 'modelsv1', 'GALAXY': 'BC03_metal', 'STARBURST': 'S17', 'BBB': 'THB21', 'TORUS': 'SKIRTOR_1P', 'XRAYS': False, 'RADIO': False, 'Blazar': 'None', 'PRIOR_energy_balance': 'Flexible', 'PRIOR_AGNfraction': True, 'PRIOR_midIR_UV': False, 'PRIOR_galaxy_only': False, 'turn_on_AGN': True}
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Option of one single dictionary for a whole catalogue is deprecated. Running "independent, -i" option.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  0
# - Sourcename:  Mrk493
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  1
# - Sourcename:  Mrk876
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 2 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 3 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 4 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 5 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 6 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 7 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 8 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 9 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 10 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 11 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 12 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 13 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 14 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 15 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 16 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 17 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 18 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 19 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 20 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 21 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 22 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 23 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 24 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 25 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
# ...
# Error: Line index 100 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 101 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 102 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 103 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 104 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 105 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 106 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 107 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 108 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 109 is out of bounds for the data array with size 2
# ======= : =======
# Process finished.
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)

# %%
# !python RUN_AGNfitter_multi.py {settings_file}
# Out:
#
#              XXXX
# ___________ XXX _________________________________________________
#             XX
#             X
#             X                       AGNfitter
#          __ X __                    ---------
#      /**\   |   /**\
# ... (*** =  o  = ***) ...........................................
#      \**/__ | __\**/
#             X              Fitting SEDs of AGN and Galaxies
#             X             in a MCMC Approach
#            xx              (Calistro Rivera et al. 2016)
#           xx
# _______ xxx______________________________________________________
#      xxxx
#
# Catalog settings:  {'path': 'C:\\Users\\PC\\AGNfitter\\', 'filename': 'C:\\Users\\PC\\AGNfitter\\catalog_example.txt', 'filetype': 'ASCII', 'name': 0, 'redshift': 1, 'freq/wl_list': [2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74, 77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137, 140, 143, 146], 'use_central_wavelength': True, 'freq/wl_format': 'wavelength', 'freq/wl_unit': Unit("micron"), 'flux_in_magAB': False, 'flux_unit': <Quantity 0.001 Jy>, 'flux_list': [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147], 'fluxerr_list': [4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70, 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 103, 106, 109, 112, 115, 118, 121, 124, 127, 130, 133, 136, 139, 142, 145, 148], 'err+10%flux_moreflex': False, 'ndflag_bool': False, 'ndflag_list': 'list', 'workingpath': 'C:\\Users\\PC\\AGNfitter\\', 'output_folder': 'C:\\Users\\PC\\AGNfitter\\OUTPUT/'}
# Filters settings:  {'dict_zarray': array([], dtype=float64), 'path': 'models/FILTERS/', 'filterset': 'example_46datapointa', '4XMM_EP5': [True, 48], '4XMM_EP4': [True, 47], '4XMM_EP3': [True, 46], '4XMM_EP2': [True, 45], 'RAD_1_4GHz': [True, 44], 'RAD_5GHz': [True, 43], 'RAD_15GHz': [True, 42], 'SPIRE500': [True, 41], 'SPIRE350': [True, 40], 'SPIRE250': [True, 39], 'PACS160': [True, 38], 'PACS100': [True, 37], 'PACS70': [True, 36], 'M1': [True, 35], 'WISE4': [True, 34], 'WISE3': [True, 33], 'IRAC4': [True, 32], 'IRAC3': [True, 31], 'WISE2': [True, 30], 'IRAC2': [True, 29], 'IRAC1': [True, 28], 'WISE1': [True, 27], 'Ks_2mass': [True, 26], 'H_2mass': [True, 25], 'J_2mass': [True, 24], 'y_PS1_good': [True, 23], 'SKY_z': [True, 22], 'z': [True, 21], 'z_PS1': [True, 20], 'SKY_i': [True, 19], 'i_PS1': [True, 18], 'i': [True, 17], 'SKY_r': [True, 16], 'r_PS1': [True, 15], 'r': [True, 14], 'SWIFT_V': [True, 13], 'SKY_g': [True, 12], 'g_PS1': [True, 11], 'g': [True, 10], 'SWIFT_B': [True, 9], 'SKY_v': [True, 8], 'u': [True, 7], 'SKY_u': [True, 6], 'SWIFT_U': [True, 5], 'SWIFT_W1': [True, 4], 'GALEX_2500': [True, 3], 'SWIFT_M2': [True, 2], 'SWIFT_W2': [True, 1], 'GALEX_1500': [True, 0], 'add_filters': False, 'add_filters_dict': {'names': [], 'filenames': [], 'freq/wl_format': [], 'freq/wl_unit': [], 'description': []}}
# Models settings:  {'path': 'models/', 'modelset': 'modelsv1', 'GALAXY': 'BC03_metal', 'STARBURST': 'S17', 'BBB': 'THB21', 'TORUS': 'SKIRTOR_1P', 'XRAYS': False, 'RADIO': False, 'Blazar': 'None', 'PRIOR_energy_balance': 'Flexible', 'PRIOR_AGNfraction': True, 'PRIOR_midIR_UV': False, 'PRIOR_galaxy_only': False, 'turn_on_AGN': True}
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Option of one single dictionary for a whole catalogue is deprecated. Running "independent, -i" option.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  0
# - Sourcename:  Mrk493
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  1
# - Sourcename:  Mrk876
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 2 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 3 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 4 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 5 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 6 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 7 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 8 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 9 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 10 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 11 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 12 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 13 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 14 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 15 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 16 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 17 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 18 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 19 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 20 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 21 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 22 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 23 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 24 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 25 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
# ...
# Error: Line index 100 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 101 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 102 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 103 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 104 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 105 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 106 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 107 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 108 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 109 is out of bounds for the data array with size 2
# ======= : =======
# Process finished.
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)

# %%
# !python RUN_AGNfitter_multi.py {settings_file}
# Out:
#
#              XXXX
# ___________ XXX _________________________________________________
#             XX
#             X
#             X                       AGNfitter
#          __ X __                    ---------
#      /**\   |   /**\
# ... (*** =  o  = ***) ...........................................
#      \**/__ | __\**/
#             X              Fitting SEDs of AGN and Galaxies
#             X             in a MCMC Approach
#            xx              (Calistro Rivera et al. 2016)
#           xx
# _______ xxx______________________________________________________
#      xxxx
#
# Catalog settings:  {'path': 'C:\\Users\\PC\\AGNfitter\\', 'filename': 'C:\\Users\\PC\\AGNfitter\\catalog_example.txt', 'filetype': 'ASCII', 'name': 0, 'redshift': 1, 'freq/wl_list': [2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74, 77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137, 140, 143, 146], 'use_central_wavelength': True, 'freq/wl_format': 'wavelength', 'freq/wl_unit': Unit("micron"), 'flux_in_magAB': False, 'flux_unit': <Quantity 0.001 Jy>, 'flux_list': [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147], 'fluxerr_list': [4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70, 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 103, 106, 109, 112, 115, 118, 121, 124, 127, 130, 133, 136, 139, 142, 145, 148], 'err+10%flux_moreflex': False, 'ndflag_bool': False, 'ndflag_list': 'list', 'workingpath': 'C:\\Users\\PC\\AGNfitter\\', 'output_folder': 'C:\\Users\\PC\\AGNfitter\\OUTPUT/'}
# Filters settings:  {'dict_zarray': array([], dtype=float64), 'path': 'models/FILTERS/', 'filterset': 'example_46datapointa', '4XMM_EP5': [True, 48], '4XMM_EP4': [True, 47], '4XMM_EP3': [True, 46], '4XMM_EP2': [True, 45], 'RAD_1_4GHz': [True, 44], 'RAD_5GHz': [True, 43], 'RAD_15GHz': [True, 42], 'SPIRE500': [True, 41], 'SPIRE350': [True, 40], 'SPIRE250': [True, 39], 'PACS160': [True, 38], 'PACS100': [True, 37], 'PACS70': [True, 36], 'M1': [True, 35], 'WISE4': [True, 34], 'WISE3': [True, 33], 'IRAC4': [True, 32], 'IRAC3': [True, 31], 'WISE2': [True, 30], 'IRAC2': [True, 29], 'IRAC1': [True, 28], 'WISE1': [True, 27], 'Ks_2mass': [True, 26], 'H_2mass': [True, 25], 'J_2mass': [True, 24], 'y_PS1_good': [True, 23], 'SKY_z': [True, 22], 'z': [True, 21], 'z_PS1': [True, 20], 'SKY_i': [True, 19], 'i_PS1': [True, 18], 'i': [True, 17], 'SKY_r': [True, 16], 'r_PS1': [True, 15], 'r': [True, 14], 'SWIFT_V': [True, 13], 'SKY_g': [True, 12], 'g_PS1': [True, 11], 'g': [True, 10], 'SWIFT_B': [True, 9], 'SKY_v': [True, 8], 'u': [True, 7], 'SKY_u': [True, 6], 'SWIFT_U': [True, 5], 'SWIFT_W1': [True, 4], 'GALEX_2500': [True, 3], 'SWIFT_M2': [True, 2], 'SWIFT_W2': [True, 1], 'GALEX_1500': [True, 0], 'add_filters': False, 'add_filters_dict': {'names': [], 'filenames': [], 'freq/wl_format': [], 'freq/wl_unit': [], 'description': []}}
# Models settings:  {'path': 'models/', 'modelset': 'modelsv1', 'GALAXY': 'BC03_metal', 'STARBURST': 'S17', 'BBB': 'THB21', 'TORUS': 'SKIRTOR_1P', 'XRAYS': False, 'RADIO': False, 'Blazar': 'None', 'PRIOR_energy_balance': 'Flexible', 'PRIOR_AGNfraction': True, 'PRIOR_midIR_UV': False, 'PRIOR_galaxy_only': False, 'turn_on_AGN': True}
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Option of one single dictionary for a whole catalogue is deprecated. Running "independent, -i" option.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  0
# - Sourcename:  Mrk493
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  1
# - Sourcename:  Mrk876
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 2 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 3 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 4 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 5 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 6 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 7 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 8 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 9 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 10 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 11 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 12 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 13 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 14 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 15 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 16 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 17 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 18 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 19 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 20 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 21 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 22 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 23 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 24 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 25 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
# ...
# Error: Line index 100 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 101 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 102 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 103 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 104 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 105 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 106 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 107 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 108 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 109 is out of bounds for the data array with size 2
# ======= : =======
# Process finished.
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)

# %%
import os

# Navigate to the AGNfitter directory
os.chdir('C:\\Users\\PC\\AGNfitter')

# Verify the contents of the directory to ensure the settings file is there
print(os.listdir())

# Run the AGNfitter script with the settings file
settings_file = 'SETTINGS_AGNfitter.py'
# !python RUN_AGNfitter_multi.py {settings_file}
# Out:
# ['-p', '.git', '.gitignore', '.ipynb_checkpoints', '.readthedocs.yaml', 'acor', 'catalog_example.txt', 'data', 'docs', 'error.log', 'example', 'functions', 'LICENSE', 'models', 'OUTPUT', 'README.md', 'readthedocs.yaml', 'RUN_AGNfitter_multi.py', 'SETTINGS_AGNfitter.py', 'UltraNest', 'Untitled.ipynb']
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
#              XXXX
# ___________ XXX _________________________________________________
#             XX
#             X
#             X                       AGNfitter
#          __ X __                    ---------
#      /**\   |   /**\
# ... (*** =  o  = ***) ...........................................
#      \**/__ | __\**/
#             X              Fitting SEDs of AGN and Galaxies
#             X             in a MCMC Approach
#            xx              (Calistro Rivera et al. 2016)
#           xx
# _______ xxx______________________________________________________
#      xxxx
#
# Catalog settings:  {'path': 'C:\\Users\\PC\\AGNfitter\\', 'filename': 'C:\\Users\\PC\\AGNfitter\\catalog_example.txt', 'filetype': 'ASCII', 'name': 0, 'redshift': 1, 'freq/wl_list': [2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74, 77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137, 140, 143, 146], 'use_central_wavelength': True, 'freq/wl_format': 'wavelength', 'freq/wl_unit': Unit("micron"), 'flux_in_magAB': False, 'flux_unit': <Quantity 0.001 Jy>, 'flux_list': [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147], 'fluxerr_list': [4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70, 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 103, 106, 109, 112, 115, 118, 121, 124, 127, 130, 133, 136, 139, 142, 145, 148], 'err+10%flux_moreflex': False, 'ndflag_bool': False, 'ndflag_list': 'list', 'workingpath': 'C:\\Users\\PC\\AGNfitter\\', 'output_folder': 'C:\\Users\\PC\\AGNfitter\\OUTPUT/'}
# Filters settings:  {'dict_zarray': array([], dtype=float64), 'path': 'models/FILTERS/', 'filterset': 'example_46datapointa', '4XMM_EP5': [True, 48], '4XMM_EP4': [True, 47], '4XMM_EP3': [True, 46], '4XMM_EP2': [True, 45], 'RAD_1_4GHz': [True, 44], 'RAD_5GHz': [True, 43], 'RAD_15GHz': [True, 42], 'SPIRE500': [True, 41], 'SPIRE350': [True, 40], 'SPIRE250': [True, 39], 'PACS160': [True, 38], 'PACS100': [True, 37], 'PACS70': [True, 36], 'M1': [True, 35], 'WISE4': [True, 34], 'WISE3': [True, 33], 'IRAC4': [True, 32], 'IRAC3': [True, 31], 'WISE2': [True, 30], 'IRAC2': [True, 29], 'IRAC1': [True, 28], 'WISE1': [True, 27], 'Ks_2mass': [True, 26], 'H_2mass': [True, 25], 'J_2mass': [True, 24], 'y_PS1_good': [True, 23], 'SKY_z': [True, 22], 'z': [True, 21], 'z_PS1': [True, 20], 'SKY_i': [True, 19], 'i_PS1': [True, 18], 'i': [True, 17], 'SKY_r': [True, 16], 'r_PS1': [True, 15], 'r': [True, 14], 'SWIFT_V': [True, 13], 'SKY_g': [True, 12], 'g_PS1': [True, 11], 'g': [True, 10], 'SWIFT_B': [True, 9], 'SKY_v': [True, 8], 'u': [True, 7], 'SKY_u': [True, 6], 'SWIFT_U': [True, 5], 'SWIFT_W1': [True, 4], 'GALEX_2500': [True, 3], 'SWIFT_M2': [True, 2], 'SWIFT_W2': [True, 1], 'GALEX_1500': [True, 0], 'add_filters': False, 'add_filters_dict': {'names': [], 'filenames': [], 'freq/wl_format': [], 'freq/wl_unit': [], 'description': []}}
# Models settings:  {'path': 'models/', 'modelset': 'modelsv1', 'GALAXY': 'BC03_metal', 'STARBURST': 'S17', 'BBB': 'THB21', 'TORUS': 'SKIRTOR_1P', 'XRAYS': False, 'RADIO': False, 'Blazar': 'None', 'PRIOR_energy_balance': 'Flexible', 'PRIOR_AGNfraction': True, 'PRIOR_midIR_UV': False, 'PRIOR_galaxy_only': False, 'turn_on_AGN': True}
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Option of one single dictionary for a whole catalogue is deprecated. Running "independent, -i" option.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  0
# - Sourcename:  Mrk493
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  1
# - Sourcename:  Mrk876
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 2 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 3 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 4 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 5 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 6 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 7 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 8 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 9 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 10 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 11 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 12 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 13 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 14 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 15 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 16 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 17 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 18 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 19 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 20 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 21 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 22 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 23 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 24 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 25 is out of bounds for the data array with size 2
# ...
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 100 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 101 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 102 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 103 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 104 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 105 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 106 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 107 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 108 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 109 is out of bounds for the data array with size 2
# ======= : =======
# Process finished.

# %%
cd C:\Users\PC\AGNfitter
# Out:
# C:\Users\PC\AGNfitter

# %%
import os
os.chdir('C:\\Users\\PC\\AGNfitter')

# %%
print(os.listdir())
# Out:
# ['-p', '.git', '.gitignore', '.ipynb_checkpoints', '.readthedocs.yaml', 'acor', 'catalog_example.txt', 'data', 'docs', 'error.log', 'example', 'functions', 'LICENSE', 'models', 'OUTPUT', 'README.md', 'readthedocs.yaml', 'RUN_AGNfitter_multi.py', 'SETTINGS_AGNfitter.py', 'UltraNest', 'Untitled.ipynb']

# %%
settings_file = 'SETTINGS_AGNfitter.py'
# !python RUN_AGNfitter_multi.py {settings_file}
# Out:
#
#              XXXX
# ___________ XXX _________________________________________________
#             XX
#             X
#             X                       AGNfitter
#          __ X __                    ---------
#      /**\   |   /**\
# ... (*** =  o  = ***) ...........................................
#      \**/__ | __\**/
#             X              Fitting SEDs of AGN and Galaxies
#             X             in a MCMC Approach
#            xx              (Calistro Rivera et al. 2016)
#           xx
# _______ xxx______________________________________________________
#      xxxx
#
# Catalog settings:  {'path': 'C:\\Users\\PC\\AGNfitter\\', 'filename': 'C:\\Users\\PC\\AGNfitter\\catalog_example.txt', 'filetype': 'ASCII', 'name': 0, 'redshift': 1, 'freq/wl_list': [2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74, 77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137, 140, 143, 146], 'use_central_wavelength': True, 'freq/wl_format': 'wavelength', 'freq/wl_unit': Unit("micron"), 'flux_in_magAB': False, 'flux_unit': <Quantity 0.001 Jy>, 'flux_list': [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147], 'fluxerr_list': [4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70, 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 103, 106, 109, 112, 115, 118, 121, 124, 127, 130, 133, 136, 139, 142, 145, 148], 'err+10%flux_moreflex': False, 'ndflag_bool': False, 'ndflag_list': 'list', 'workingpath': 'C:\\Users\\PC\\AGNfitter\\', 'output_folder': 'C:\\Users\\PC\\AGNfitter\\OUTPUT/'}
# Filters settings:  {'dict_zarray': array([], dtype=float64), 'path': 'models/FILTERS/', 'filterset': 'example_46datapointa', '4XMM_EP5': [True, 48], '4XMM_EP4': [True, 47], '4XMM_EP3': [True, 46], '4XMM_EP2': [True, 45], 'RAD_1_4GHz': [True, 44], 'RAD_5GHz': [True, 43], 'RAD_15GHz': [True, 42], 'SPIRE500': [True, 41], 'SPIRE350': [True, 40], 'SPIRE250': [True, 39], 'PACS160': [True, 38], 'PACS100': [True, 37], 'PACS70': [True, 36], 'M1': [True, 35], 'WISE4': [True, 34], 'WISE3': [True, 33], 'IRAC4': [True, 32], 'IRAC3': [True, 31], 'WISE2': [True, 30], 'IRAC2': [True, 29], 'IRAC1': [True, 28], 'WISE1': [True, 27], 'Ks_2mass': [True, 26], 'H_2mass': [True, 25], 'J_2mass': [True, 24], 'y_PS1_good': [True, 23], 'SKY_z': [True, 22], 'z': [True, 21], 'z_PS1': [True, 20], 'SKY_i': [True, 19], 'i_PS1': [True, 18], 'i': [True, 17], 'SKY_r': [True, 16], 'r_PS1': [True, 15], 'r': [True, 14], 'SWIFT_V': [True, 13], 'SKY_g': [True, 12], 'g_PS1': [True, 11], 'g': [True, 10], 'SWIFT_B': [True, 9], 'SKY_v': [True, 8], 'u': [True, 7], 'SKY_u': [True, 6], 'SWIFT_U': [True, 5], 'SWIFT_W1': [True, 4], 'GALEX_2500': [True, 3], 'SWIFT_M2': [True, 2], 'SWIFT_W2': [True, 1], 'GALEX_1500': [True, 0], 'add_filters': False, 'add_filters_dict': {'names': [], 'filenames': [], 'freq/wl_format': [], 'freq/wl_unit': [], 'description': []}}
# Models settings:  {'path': 'models/', 'modelset': 'modelsv1', 'GALAXY': 'BC03_metal', 'STARBURST': 'S17', 'BBB': 'THB21', 'TORUS': 'SKIRTOR_1P', 'XRAYS': False, 'RADIO': False, 'Blazar': 'None', 'PRIOR_energy_balance': 'Flexible', 'PRIOR_AGNfraction': True, 'PRIOR_midIR_UV': False, 'PRIOR_galaxy_only': False, 'turn_on_AGN': True}
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Option of one single dictionary for a whole catalogue is deprecated. Running "independent, -i" option.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  0
# - Sourcename:  Mrk493
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  1
# - Sourcename:  Mrk876
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 2 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 3 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 4 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 5 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 6 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 7 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 8 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 9 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 10 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 11 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 12 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 13 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 14 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 15 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 16 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 17 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 18 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 19 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 20 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 21 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 22 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 23 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 24 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 25 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
# ...
# Error: Line index 100 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 101 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 102 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 103 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 104 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 105 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 106 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 107 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 108 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 109 is out of bounds for the data array with size 2
# ======= : =======
# Process finished.
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)

# %%
import os

# Change directory to where the AGNfitter files are located
os.chdir('C:\\Users\\PC\\AGNfitter')

# Verify that the necessary files are present
print(os.listdir())
# Out:
# ['-p', '.git', '.gitignore', '.ipynb_checkpoints', '.readthedocs.yaml', 'acor', 'catalog_example.txt', 'data', 'docs', 'error.log', 'example', 'functions', 'LICENSE', 'models', 'OUTPUT', 'README.md', 'readthedocs.yaml', 'RUN_AGNfitter_multi.py', 'SETTINGS_AGNfitter.py', 'UltraNest', 'Untitled.ipynb']

# %%
settings_file = 'SETTINGS_AGNfitter.py'
# !python RUN_AGNfitter_multi.py {settings_file}
# Out:
#
#              XXXX
# ___________ XXX _________________________________________________
#             XX
#             X
#             X                       AGNfitter
#          __ X __                    ---------
#      /**\   |   /**\
# ... (*** =  o  = ***) ...........................................
#      \**/__ | __\**/
#             X              Fitting SEDs of AGN and Galaxies
#             X             in a MCMC Approach
#            xx              (Calistro Rivera et al. 2016)
#           xx
# _______ xxx______________________________________________________
#      xxxx
#
# Catalog settings:  {'path': 'C:\\Users\\PC\\AGNfitter\\', 'filename': 'C:\\Users\\PC\\AGNfitter\\catalog_example.txt', 'filetype': 'ASCII', 'name': 0, 'redshift': 1, 'freq/wl_list': [2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74, 77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137, 140, 143, 146], 'use_central_wavelength': True, 'freq/wl_format': 'wavelength', 'freq/wl_unit': Unit("micron"), 'flux_in_magAB': False, 'flux_unit': <Quantity 0.001 Jy>, 'flux_list': [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147], 'fluxerr_list': [4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70, 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 103, 106, 109, 112, 115, 118, 121, 124, 127, 130, 133, 136, 139, 142, 145, 148], 'err+10%flux_moreflex': False, 'ndflag_bool': False, 'ndflag_list': 'list', 'workingpath': 'C:\\Users\\PC\\AGNfitter\\', 'output_folder': 'C:\\Users\\PC\\AGNfitter\\OUTPUT/'}
# Filters settings:  {'dict_zarray': array([], dtype=float64), 'path': 'models/FILTERS/', 'filterset': 'example_46datapointa', '4XMM_EP5': [True, 48], '4XMM_EP4': [True, 47], '4XMM_EP3': [True, 46], '4XMM_EP2': [True, 45], 'RAD_1_4GHz': [True, 44], 'RAD_5GHz': [True, 43], 'RAD_15GHz': [True, 42], 'SPIRE500': [True, 41], 'SPIRE350': [True, 40], 'SPIRE250': [True, 39], 'PACS160': [True, 38], 'PACS100': [True, 37], 'PACS70': [True, 36], 'M1': [True, 35], 'WISE4': [True, 34], 'WISE3': [True, 33], 'IRAC4': [True, 32], 'IRAC3': [True, 31], 'WISE2': [True, 30], 'IRAC2': [True, 29], 'IRAC1': [True, 28], 'WISE1': [True, 27], 'Ks_2mass': [True, 26], 'H_2mass': [True, 25], 'J_2mass': [True, 24], 'y_PS1_good': [True, 23], 'SKY_z': [True, 22], 'z': [True, 21], 'z_PS1': [True, 20], 'SKY_i': [True, 19], 'i_PS1': [True, 18], 'i': [True, 17], 'SKY_r': [True, 16], 'r_PS1': [True, 15], 'r': [True, 14], 'SWIFT_V': [True, 13], 'SKY_g': [True, 12], 'g_PS1': [True, 11], 'g': [True, 10], 'SWIFT_B': [True, 9], 'SKY_v': [True, 8], 'u': [True, 7], 'SKY_u': [True, 6], 'SWIFT_U': [True, 5], 'SWIFT_W1': [True, 4], 'GALEX_2500': [True, 3], 'SWIFT_M2': [True, 2], 'SWIFT_W2': [True, 1], 'GALEX_1500': [True, 0], 'add_filters': False, 'add_filters_dict': {'names': [], 'filenames': [], 'freq/wl_format': [], 'freq/wl_unit': [], 'description': []}}
# Models settings:  {'path': 'models/', 'modelset': 'modelsv1', 'GALAXY': 'BC03_metal', 'STARBURST': 'S17', 'BBB': 'THB21', 'TORUS': 'SKIRTOR_1P', 'XRAYS': False, 'RADIO': False, 'Blazar': 'None', 'PRIOR_energy_balance': 'Flexible', 'PRIOR_AGNfraction': True, 'PRIOR_midIR_UV': False, 'PRIOR_galaxy_only': False, 'turn_on_AGN': True}
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Option of one single dictionary for a whole catalogue is deprecated. Running "independent, -i" option.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  0
# - Sourcename:  Mrk493
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  1
# - Sourcename:  Mrk876
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 2 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 3 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 4 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 5 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 6 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 7 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 8 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 9 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 10 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 11 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 12 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 13 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 14 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 15 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 16 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 17 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 18 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 19 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 20 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 21 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 22 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 23 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 24 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 25 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
# ...
# Error: Line index 100 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 101 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 102 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 103 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 104 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 105 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 106 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 107 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 108 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 109 is out of bounds for the data array with size 2
# ======= : =======
# Process finished.
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)

# %%
import os

# Change directory to where the AGNfitter files are located
os.chdir('C:\\Users\\PC\\AGNfitter')

# Verify the directory change
print("Current Working Directory: ", os.getcwd())

# List the files in the directory to ensure the necessary files are present
print("Directory Listing: ", os.listdir())
# Out:
# Current Working Directory:  C:\Users\PC\AGNfitter
# Directory Listing:  ['-p', '.git', '.gitignore', '.ipynb_checkpoints', '.readthedocs.yaml', 'acor', 'catalog_example.txt', 'data', 'docs', 'error.log', 'example', 'functions', 'LICENSE', 'models', 'OUTPUT', 'README.md', 'readthedocs.yaml', 'RUN_AGNfitter_multi.py', 'SETTINGS_AGNfitter.py', 'UltraNest', 'Untitled.ipynb']

# %%
# Specify the settings file
settings_file = 'SETTINGS_AGNfitter.py'

# Run the AGNfitter script
# !python RUN_AGNfitter_multi.py {settings_file}
# Out:
#
#              XXXX
# ___________ XXX _________________________________________________
#             XX
#             X
#             X                       AGNfitter
#          __ X __                    ---------
#      /**\   |   /**\
# ... (*** =  o  = ***) ...........................................
#      \**/__ | __\**/
#             X              Fitting SEDs of AGN and Galaxies
#             X             in a MCMC Approach
#            xx              (Calistro Rivera et al. 2016)
#           xx
# _______ xxx______________________________________________________
#      xxxx
#
# Catalog settings:  {'path': 'C:\\Users\\PC\\AGNfitter\\', 'filename': 'C:\\Users\\PC\\AGNfitter\\catalog_example.txt', 'filetype': 'ASCII', 'name': 0, 'redshift': 1, 'freq/wl_list': [2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74, 77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137, 140, 143, 146], 'use_central_wavelength': True, 'freq/wl_format': 'wavelength', 'freq/wl_unit': Unit("micron"), 'flux_in_magAB': False, 'flux_unit': <Quantity 0.001 Jy>, 'flux_list': [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147], 'fluxerr_list': [4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70, 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 103, 106, 109, 112, 115, 118, 121, 124, 127, 130, 133, 136, 139, 142, 145, 148], 'err+10%flux_moreflex': False, 'ndflag_bool': False, 'ndflag_list': 'list', 'workingpath': 'C:\\Users\\PC\\AGNfitter\\', 'output_folder': 'C:\\Users\\PC\\AGNfitter\\OUTPUT/'}
# Filters settings:  {'dict_zarray': array([], dtype=float64), 'path': 'models/FILTERS/', 'filterset': 'example_46datapointa', '4XMM_EP5': [True, 48], '4XMM_EP4': [True, 47], '4XMM_EP3': [True, 46], '4XMM_EP2': [True, 45], 'RAD_1_4GHz': [True, 44], 'RAD_5GHz': [True, 43], 'RAD_15GHz': [True, 42], 'SPIRE500': [True, 41], 'SPIRE350': [True, 40], 'SPIRE250': [True, 39], 'PACS160': [True, 38], 'PACS100': [True, 37], 'PACS70': [True, 36], 'M1': [True, 35], 'WISE4': [True, 34], 'WISE3': [True, 33], 'IRAC4': [True, 32], 'IRAC3': [True, 31], 'WISE2': [True, 30], 'IRAC2': [True, 29], 'IRAC1': [True, 28], 'WISE1': [True, 27], 'Ks_2mass': [True, 26], 'H_2mass': [True, 25], 'J_2mass': [True, 24], 'y_PS1_good': [True, 23], 'SKY_z': [True, 22], 'z': [True, 21], 'z_PS1': [True, 20], 'SKY_i': [True, 19], 'i_PS1': [True, 18], 'i': [True, 17], 'SKY_r': [True, 16], 'r_PS1': [True, 15], 'r': [True, 14], 'SWIFT_V': [True, 13], 'SKY_g': [True, 12], 'g_PS1': [True, 11], 'g': [True, 10], 'SWIFT_B': [True, 9], 'SKY_v': [True, 8], 'u': [True, 7], 'SKY_u': [True, 6], 'SWIFT_U': [True, 5], 'SWIFT_W1': [True, 4], 'GALEX_2500': [True, 3], 'SWIFT_M2': [True, 2], 'SWIFT_W2': [True, 1], 'GALEX_1500': [True, 0], 'add_filters': False, 'add_filters_dict': {'names': [], 'filenames': [], 'freq/wl_format': [], 'freq/wl_unit': [], 'description': []}}
# Models settings:  {'path': 'models/', 'modelset': 'modelsv1', 'GALAXY': 'BC03_metal', 'STARBURST': 'S17', 'BBB': 'THB21', 'TORUS': 'SKIRTOR_1P', 'XRAYS': False, 'RADIO': False, 'Blazar': 'None', 'PRIOR_energy_balance': 'Flexible', 'PRIOR_AGNfraction': True, 'PRIOR_midIR_UV': False, 'PRIOR_galaxy_only': False, 'turn_on_AGN': True}
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Option of one single dictionary for a whole catalogue is deprecated. Running "independent, -i" option.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  0
# - Sourcename:  Mrk493
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  1
# - Sourcename:  Mrk876
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 2 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 3 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 4 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 5 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 6 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 7 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 8 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 9 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 10 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 11 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 12 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 13 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 14 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 15 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 16 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 17 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 18 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 19 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 20 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 21 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 22 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 23 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 24 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 25 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
# ...
# Error: Line index 100 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 101 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 102 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 103 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 104 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 105 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 106 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 107 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 108 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 109 is out of bounds for the data array with size 2
# ======= : =======
# Process finished.
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)

# %%
import os

# Check if the catalog file exists
catalog_path = 'C:\\Users\\PC\\AGNfitter\\catalog_example.txt'
if os.path.isfile(catalog_path):
    print("Catalog file exists.")
else:
    print("Catalog file does not exist.")
# Out:
# Catalog file exists.

# %%
import os

# Change directory to where the AGNfitter files are located
os.chdir('C:\\Users\\PC\\AGNfitter')

# Verify the directory change
print("Current Working Directory: ", os.getcwd())

# List the files in the directory to ensure the necessary files are present
print("Directory Listing: ", os.listdir())
# Out:
# Current Working Directory:  C:\Users\PC\AGNfitter
# Directory Listing:  ['-p', '.git', '.gitignore', '.ipynb_checkpoints', '.readthedocs.yaml', 'acor', 'catalog_example.txt', 'data', 'docs', 'error.log', 'example', 'functions', 'LICENSE', 'models', 'OUTPUT', 'README.md', 'readthedocs.yaml', 'RUN_AGNfitter_multi.py', 'SETTINGS_AGNfitter.py', 'UltraNest', 'Untitled.ipynb']

# %%
import os

# Change directory to where the AGNfitter files are located
os.chdir('C:\\Users\\PC\\AGNfitter')

# Verify the directory change
print("Current Working Directory: ", os.getcwd())

# List the files in the directory to ensure the necessary files are present
print("Directory Listing: ", os.listdir())
# Out:
# Current Working Directory:  C:\Users\PC\AGNfitter
# Directory Listing:  ['-p', '.git', '.gitignore', '.ipynb_checkpoints', '.readthedocs.yaml', 'acor', 'catalog_example.txt', 'data', 'docs', 'error.log', 'example', 'functions', 'LICENSE', 'models', 'OUTPUT', 'README.md', 'readthedocs.yaml', 'RUN_AGNfitter_multi.py', 'SETTINGS_AGNfitter.py', 'UltraNest', 'Untitled.ipynb']

# %%
# Run the AGNfitter script with the settings file
settings_file = 'SETTINGS_AGNfitter.py'
# !python RUN_AGNfitter_multi.py {settings_file}
# Out:
#
#              XXXX
# ___________ XXX _________________________________________________
#             XX
#             X
#             X                       AGNfitter
#          __ X __                    ---------
#      /**\   |   /**\
# ... (*** =  o  = ***) ...........................................
#      \**/__ | __\**/
#             X              Fitting SEDs of AGN and Galaxies
#             X             in a MCMC Approach
#            xx              (Calistro Rivera et al. 2016)
#           xx
# _______ xxx______________________________________________________
#      xxxx
#
# Catalog settings:  {'path': 'C:\\Users\\PC\\AGNfitter\\', 'filename': 'C:\\Users\\PC\\AGNfitter\\catalog_example.txt', 'filetype': 'ASCII', 'name': 0, 'redshift': 1, 'freq/wl_list': [2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74, 77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137, 140, 143, 146], 'use_central_wavelength': True, 'freq/wl_format': 'wavelength', 'freq/wl_unit': Unit("micron"), 'flux_in_magAB': False, 'flux_unit': <Quantity 0.001 Jy>, 'flux_list': [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147], 'fluxerr_list': [4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70, 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 103, 106, 109, 112, 115, 118, 121, 124, 127, 130, 133, 136, 139, 142, 145, 148], 'err+10%flux_moreflex': False, 'ndflag_bool': False, 'ndflag_list': 'list', 'workingpath': 'C:\\Users\\PC\\AGNfitter\\', 'output_folder': 'C:\\Users\\PC\\AGNfitter\\OUTPUT/'}
# Filters settings:  {'dict_zarray': array([], dtype=float64), 'path': 'models/FILTERS/', 'filterset': 'example_46datapointa', '4XMM_EP5': [True, 48], '4XMM_EP4': [True, 47], '4XMM_EP3': [True, 46], '4XMM_EP2': [True, 45], 'RAD_1_4GHz': [True, 44], 'RAD_5GHz': [True, 43], 'RAD_15GHz': [True, 42], 'SPIRE500': [True, 41], 'SPIRE350': [True, 40], 'SPIRE250': [True, 39], 'PACS160': [True, 38], 'PACS100': [True, 37], 'PACS70': [True, 36], 'M1': [True, 35], 'WISE4': [True, 34], 'WISE3': [True, 33], 'IRAC4': [True, 32], 'IRAC3': [True, 31], 'WISE2': [True, 30], 'IRAC2': [True, 29], 'IRAC1': [True, 28], 'WISE1': [True, 27], 'Ks_2mass': [True, 26], 'H_2mass': [True, 25], 'J_2mass': [True, 24], 'y_PS1_good': [True, 23], 'SKY_z': [True, 22], 'z': [True, 21], 'z_PS1': [True, 20], 'SKY_i': [True, 19], 'i_PS1': [True, 18], 'i': [True, 17], 'SKY_r': [True, 16], 'r_PS1': [True, 15], 'r': [True, 14], 'SWIFT_V': [True, 13], 'SKY_g': [True, 12], 'g_PS1': [True, 11], 'g': [True, 10], 'SWIFT_B': [True, 9], 'SKY_v': [True, 8], 'u': [True, 7], 'SKY_u': [True, 6], 'SWIFT_U': [True, 5], 'SWIFT_W1': [True, 4], 'GALEX_2500': [True, 3], 'SWIFT_M2': [True, 2], 'SWIFT_W2': [True, 1], 'GALEX_1500': [True, 0], 'add_filters': False, 'add_filters_dict': {'names': [], 'filenames': [], 'freq/wl_format': [], 'freq/wl_unit': [], 'description': []}}
# Models settings:  {'path': 'models/', 'modelset': 'modelsv1', 'GALAXY': 'BC03_metal', 'STARBURST': 'S17', 'BBB': 'THB21', 'TORUS': 'SKIRTOR_1P', 'XRAYS': False, 'RADIO': False, 'Blazar': 'None', 'PRIOR_energy_balance': 'Flexible', 'PRIOR_AGNfraction': True, 'PRIOR_midIR_UV': False, 'PRIOR_galaxy_only': False, 'turn_on_AGN': True}
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Option of one single dictionary for a whole catalogue is deprecated. Running "independent, -i" option.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  0
# - Sourcename:  Mrk493
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  1
# - Sourcename:  Mrk876
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 2 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 3 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 4 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 5 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 6 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 7 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 8 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 9 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 10 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 11 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 12 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 13 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 14 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 15 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 16 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 17 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 18 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 19 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 20 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 21 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 22 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 23 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 24 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 25 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
# ...
# Error: Line index 100 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 101 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 102 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 103 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 104 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 105 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 106 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 107 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 108 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 109 is out of bounds for the data array with size 2
# ======= : =======
# Process finished.
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)

# %%
import os

# Define the path to the catalog file
catalog_path = 'C:\\Users\\PC\\AGNfitter\\catalog_example.txt'

# Check if the catalog file exists and print the result
if os.path.isfile(catalog_path):
    print("Catalog file exists at:", catalog_path)
else:
    print("Catalog file does not exist. Please check the path:", catalog_path)
# Out:
# Catalog file exists at: C:\Users\PC\AGNfitter\catalog_example.txt

# %%
# Run the AGNfitter script with the settings file
settings_file = 'SETTINGS_AGNfitter.py'
# !python RUN_AGNfitter_multi.py {settings_file}
# Out:
#
#              XXXX
# ___________ XXX _________________________________________________
#             XX
#             X
#             X                       AGNfitter
#          __ X __                    ---------
#      /**\   |   /**\
# ... (*** =  o  = ***) ...........................................
#      \**/__ | __\**/
#             X              Fitting SEDs of AGN and Galaxies
#             X             in a MCMC Approach
#            xx              (Calistro Rivera et al. 2016)
#           xx
# _______ xxx______________________________________________________
#      xxxx
#
# Catalog settings:  {'path': 'C:\\Users\\PC\\AGNfitter\\', 'filename': 'C:\\Users\\PC\\AGNfitter\\catalog_example.txt', 'filetype': 'ASCII', 'name': 0, 'redshift': 1, 'freq/wl_list': [2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74, 77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137, 140, 143, 146], 'use_central_wavelength': True, 'freq/wl_format': 'wavelength', 'freq/wl_unit': Unit("micron"), 'flux_in_magAB': False, 'flux_unit': <Quantity 0.001 Jy>, 'flux_list': [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147], 'fluxerr_list': [4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70, 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 103, 106, 109, 112, 115, 118, 121, 124, 127, 130, 133, 136, 139, 142, 145, 148], 'err+10%flux_moreflex': False, 'ndflag_bool': False, 'ndflag_list': 'list', 'workingpath': 'C:\\Users\\PC\\AGNfitter\\', 'output_folder': 'C:\\Users\\PC\\AGNfitter\\OUTPUT/'}
# Filters settings:  {'dict_zarray': array([], dtype=float64), 'path': 'models/FILTERS/', 'filterset': 'example_46datapointa', '4XMM_EP5': [True, 48], '4XMM_EP4': [True, 47], '4XMM_EP3': [True, 46], '4XMM_EP2': [True, 45], 'RAD_1_4GHz': [True, 44], 'RAD_5GHz': [True, 43], 'RAD_15GHz': [True, 42], 'SPIRE500': [True, 41], 'SPIRE350': [True, 40], 'SPIRE250': [True, 39], 'PACS160': [True, 38], 'PACS100': [True, 37], 'PACS70': [True, 36], 'M1': [True, 35], 'WISE4': [True, 34], 'WISE3': [True, 33], 'IRAC4': [True, 32], 'IRAC3': [True, 31], 'WISE2': [True, 30], 'IRAC2': [True, 29], 'IRAC1': [True, 28], 'WISE1': [True, 27], 'Ks_2mass': [True, 26], 'H_2mass': [True, 25], 'J_2mass': [True, 24], 'y_PS1_good': [True, 23], 'SKY_z': [True, 22], 'z': [True, 21], 'z_PS1': [True, 20], 'SKY_i': [True, 19], 'i_PS1': [True, 18], 'i': [True, 17], 'SKY_r': [True, 16], 'r_PS1': [True, 15], 'r': [True, 14], 'SWIFT_V': [True, 13], 'SKY_g': [True, 12], 'g_PS1': [True, 11], 'g': [True, 10], 'SWIFT_B': [True, 9], 'SKY_v': [True, 8], 'u': [True, 7], 'SKY_u': [True, 6], 'SWIFT_U': [True, 5], 'SWIFT_W1': [True, 4], 'GALEX_2500': [True, 3], 'SWIFT_M2': [True, 2], 'SWIFT_W2': [True, 1], 'GALEX_1500': [True, 0], 'add_filters': False, 'add_filters_dict': {'names': [], 'filenames': [], 'freq/wl_format': [], 'freq/wl_unit': [], 'description': []}}
# Models settings:  {'path': 'models/', 'modelset': 'modelsv1', 'GALAXY': 'BC03_metal', 'STARBURST': 'S17', 'BBB': 'THB21', 'TORUS': 'SKIRTOR_1P', 'XRAYS': False, 'RADIO': False, 'Blazar': 'None', 'PRIOR_energy_balance': 'Flexible', 'PRIOR_AGNfraction': True, 'PRIOR_midIR_UV': False, 'PRIOR_galaxy_only': False, 'turn_on_AGN': True}
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Option of one single dictionary for a whole catalogue is deprecated. Running "independent, -i" option.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  0
# - Sourcename:  Mrk493
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  1
# - Sourcename:  Mrk876
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 2 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 3 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 4 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 5 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 6 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 7 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 8 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 9 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 10 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 11 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 12 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 13 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 14 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 15 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 16 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 17 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 18 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 19 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 20 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 21 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 22 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 23 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 24 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 25 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
# ...
# Error: Line index 100 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 101 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 102 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 103 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 104 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 105 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 106 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 107 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 108 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 109 is out of bounds for the data array with size 2
# ======= : =======
# Process finished.
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)
# C:\Users\PC\AGNfitter\functions\PLOTandWRITE_AGNfitter.py:718: RuntimeWarning: divide by zero encountered in log10
#   TOinterp = scipy.interpolate.interp1d(all_tor_nus, np.log10(tor_Fnus.flatten()), kind='linear', bounds_error=False, fill_value=-100)

# %%
import subprocess

# Path to the AGNfitter directory and settings file
agnfitter_path = 'C:\\Users\\PC\\AGNfitter\\'
settings_file = 'SETTINGS_AGNfitter.py'

# Command to run the AGNfitter script
command = ['python', os.path.join(agnfitter_path, 'RUN_AGNfitter_multi.py'), settings_file]

# Run the command and print output
try:
    subprocess.run(command, check=True)
    print("AGNfitter script ran successfully.")
except subprocess.CalledProcessError as e:
    print("Error running AGNfitter script:", e)
# Out:
# AGNfitter script ran successfully.

# %%
import subprocess
import os

# Define the path to the AGNfitter directory and settings file
agnfitter_path = 'C:\\Users\\PC\\AGNfitter\\'
settings_file = 'SETTINGS_AGNfitter.py'

# Command to run the AGNfitter script
command = ['python', os.path.join(agnfitter_path, 'RUN_AGNfitter_multi.py'), settings_file]

# Run the command and capture output
try:
    result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    print("AGNfitter script ran successfully.")
    print(result.stdout)
except subprocess.CalledProcessError as e:
    print("Error running AGNfitter script:")
    print(e.stderr)
    print(e.stdout)
# Out:
# AGNfitter script ran successfully.
#
#              XXXX
# ___________ XXX _________________________________________________
#             XX
#             X
#             X                       AGNfitter
#          __ X __                    ---------
#      /**\   |   /**\
# ... (*** =  o  = ***) ...........................................
#      \**/__ | __\**/
#             X              Fitting SEDs of AGN and Galaxies
#             X             in a MCMC Approach
#            xx              (Calistro Rivera et al. 2016)
#           xx
# _______ xxx______________________________________________________
#      xxxx
#
# Catalog settings:  {'path': 'C:\\Users\\PC\\AGNfitter\\', 'filename': 'C:\\Users\\PC\\AGNfitter\\catalog_example.txt', 'filetype': 'ASCII', 'name': 0, 'redshift': 1, 'freq/wl_list': [2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74, 77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137, 140, 143, 146], 'use_central_wavelength': True, 'freq/wl_format': 'wavelength', 'freq/wl_unit': Unit("micron"), 'flux_in_magAB': False, 'flux_unit': <Quantity 0.001 Jy>, 'flux_list': [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147], 'fluxerr_list': [4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70, 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 103, 106, 109, 112, 115, 118, 121, 124, 127, 130, 133, 136, 139, 142, 145, 148], 'err+10%flux_moreflex': False, 'ndflag_bool': False, 'ndflag_list': 'list', 'workingpath': 'C:\\Users\\PC\\AGNfitter\\', 'output_folder': 'C:\\Users\\PC\\AGNfitter\\OUTPUT/'}
# Filters settings:  {'dict_zarray': array([], dtype=float64), 'path': 'models/FILTERS/', 'filterset': 'example_46datapointa', '4XMM_EP5': [True, 48], '4XMM_EP4': [True, 47], '4XMM_EP3': [True, 46], '4XMM_EP2': [True, 45], 'RAD_1_4GHz': [True, 44], 'RAD_5GHz': [True, 43], 'RAD_15GHz': [True, 42], 'SPIRE500': [True, 41], 'SPIRE350': [True, 40], 'SPIRE250': [True, 39], 'PACS160': [True, 38], 'PACS100': [True, 37], 'PACS70': [True, 36], 'M1': [True, 35], 'WISE4': [True, 34], 'WISE3': [True, 33], 'IRAC4': [True, 32], 'IRAC3': [True, 31], 'WISE2': [True, 30], 'IRAC2': [True, 29], 'IRAC1': [True, 28], 'WISE1': [True, 27], 'Ks_2mass': [True, 26], 'H_2mass': [True, 25], 'J_2mass': [True, 24], 'y_PS1_good': [True, 23], 'SKY_z': [True, 22], 'z': [True, 21], 'z_PS1': [True, 20], 'SKY_i': [True, 19], 'i_PS1': [True, 18], 'i': [True, 17], 'SKY_r': [True, 16], 'r_PS1': [True, 15], 'r': [True, 14], 'SWIFT_V': [True, 13], 'SKY_g': [True, 12], 'g_PS1': [True, 11], 'g': [True, 10], 'SWIFT_B': [True, 9], 'SKY_v': [True, 8], 'u': [True, 7], 'SKY_u': [True, 6], 'SWIFT_U': [True, 5], 'SWIFT_W1': [True, 4], 'GALEX_2500': [True, 3], 'SWIFT_M2': [True, 2], 'SWIFT_W2': [True, 1], 'GALEX_1500': [True, 0], 'add_filters': False, 'add_filters_dict': {'names': [], 'filenames': [], 'freq/wl_format': [], 'freq/wl_unit': [], 'description': []}}
# Models settings:  {'path': 'models/', 'modelset': 'modelsv1', 'GALAXY': 'BC03_metal', 'STARBURST': 'S17', 'BBB': 'THB21', 'TORUS': 'SKIRTOR_1P', 'XRAYS': False, 'RADIO': False, 'Blazar': 'None', 'PRIOR_energy_balance': 'Flexible', 'PRIOR_AGNfraction': True, 'PRIOR_midIR_UV': False, 'PRIOR_galaxy_only': False, 'turn_on_AGN': True}
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Option of one single dictionary for a whole catalogue is deprecated. Running "independent, -i" option.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  0
# - Sourcename:  Mrk493
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  1
# - Sourcename:  Mrk876
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 2 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 3 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 4 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 5 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 6 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 7 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 8 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 9 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 10 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 11 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 12 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 13 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 14 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 15 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 16 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 17 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 18 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 19 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 20 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 21 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 22 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 23 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 24 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 25 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
# ...
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 100 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 101 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 102 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 103 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 104 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 105 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 106 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 107 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 108 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 109 is out of bounds for the data array with size 2
# ======= : =======
# Process finished.

# %%
import subprocess
import os

# Define the path to the AGNfitter directory and settings file
agnfitter_path = 'C:\\Users\\PC\\AGNfitter\\'
settings_file = 'SETTINGS_AGNfitter.py'

# Check if the catalog file exists
catalog_file = os.path.join(agnfitter_path, 'catalog_example.txt')
if not os.path.isfile(catalog_file):
    print(f"Catalog file does not exist at: {catalog_file}")
else:
    # Command to run the AGNfitter script
    command = ['python', os.path.join(agnfitter_path, 'RUN_AGNfitter_multi.py'), settings_file]

    # Run the command and capture output
    try:
        result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
        print("AGNfitter script ran successfully.")
        print(result.stdout)
    except subprocess.CalledProcessError as e:
        print("Error running AGNfitter script:")
        print(e.stderr)
        print(e.stdout)
# Out:
# AGNfitter script ran successfully.
#
#              XXXX
# ___________ XXX _________________________________________________
#             XX
#             X
#             X                       AGNfitter
#          __ X __                    ---------
#      /**\   |   /**\
# ... (*** =  o  = ***) ...........................................
#      \**/__ | __\**/
#             X              Fitting SEDs of AGN and Galaxies
#             X             in a MCMC Approach
#            xx              (Calistro Rivera et al. 2016)
#           xx
# _______ xxx______________________________________________________
#      xxxx
#
# Catalog settings:  {'path': 'C:\\Users\\PC\\AGNfitter\\', 'filename': 'C:\\Users\\PC\\AGNfitter\\catalog_example.txt', 'filetype': 'ASCII', 'name': 0, 'redshift': 1, 'freq/wl_list': [2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74, 77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137, 140, 143, 146], 'use_central_wavelength': True, 'freq/wl_format': 'wavelength', 'freq/wl_unit': Unit("micron"), 'flux_in_magAB': False, 'flux_unit': <Quantity 0.001 Jy>, 'flux_list': [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147], 'fluxerr_list': [4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70, 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 103, 106, 109, 112, 115, 118, 121, 124, 127, 130, 133, 136, 139, 142, 145, 148], 'err+10%flux_moreflex': False, 'ndflag_bool': False, 'ndflag_list': 'list', 'workingpath': 'C:\\Users\\PC\\AGNfitter\\', 'output_folder': 'C:\\Users\\PC\\AGNfitter\\OUTPUT/'}
# Filters settings:  {'dict_zarray': array([], dtype=float64), 'path': 'models/FILTERS/', 'filterset': 'example_46datapointa', '4XMM_EP5': [True, 48], '4XMM_EP4': [True, 47], '4XMM_EP3': [True, 46], '4XMM_EP2': [True, 45], 'RAD_1_4GHz': [True, 44], 'RAD_5GHz': [True, 43], 'RAD_15GHz': [True, 42], 'SPIRE500': [True, 41], 'SPIRE350': [True, 40], 'SPIRE250': [True, 39], 'PACS160': [True, 38], 'PACS100': [True, 37], 'PACS70': [True, 36], 'M1': [True, 35], 'WISE4': [True, 34], 'WISE3': [True, 33], 'IRAC4': [True, 32], 'IRAC3': [True, 31], 'WISE2': [True, 30], 'IRAC2': [True, 29], 'IRAC1': [True, 28], 'WISE1': [True, 27], 'Ks_2mass': [True, 26], 'H_2mass': [True, 25], 'J_2mass': [True, 24], 'y_PS1_good': [True, 23], 'SKY_z': [True, 22], 'z': [True, 21], 'z_PS1': [True, 20], 'SKY_i': [True, 19], 'i_PS1': [True, 18], 'i': [True, 17], 'SKY_r': [True, 16], 'r_PS1': [True, 15], 'r': [True, 14], 'SWIFT_V': [True, 13], 'SKY_g': [True, 12], 'g_PS1': [True, 11], 'g': [True, 10], 'SWIFT_B': [True, 9], 'SKY_v': [True, 8], 'u': [True, 7], 'SKY_u': [True, 6], 'SWIFT_U': [True, 5], 'SWIFT_W1': [True, 4], 'GALEX_2500': [True, 3], 'SWIFT_M2': [True, 2], 'SWIFT_W2': [True, 1], 'GALEX_1500': [True, 0], 'add_filters': False, 'add_filters_dict': {'names': [], 'filenames': [], 'freq/wl_format': [], 'freq/wl_unit': [], 'description': []}}
# Models settings:  {'path': 'models/', 'modelset': 'modelsv1', 'GALAXY': 'BC03_metal', 'STARBURST': 'S17', 'BBB': 'THB21', 'TORUS': 'SKIRTOR_1P', 'XRAYS': False, 'RADIO': False, 'Blazar': 'None', 'PRIOR_energy_balance': 'Flexible', 'PRIOR_AGNfraction': True, 'PRIOR_midIR_UV': False, 'PRIOR_galaxy_only': False, 'turn_on_AGN': True}
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Option of one single dictionary for a whole catalogue is deprecated. Running "independent, -i" option.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  0
# - Sourcename:  Mrk493
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  1
# - Sourcename:  Mrk876
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 2 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 3 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 4 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 5 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 6 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 7 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 8 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 9 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 10 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 11 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 12 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 13 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 14 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 15 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 16 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 17 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 18 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 19 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 20 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 21 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 22 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 23 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 24 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 25 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
# ...
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 100 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 101 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 102 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 103 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 104 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 105 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 106 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 107 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 108 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 109 is out of bounds for the data array with size 2
# ======= : =======
# Process finished.

# %%
import os

# Define the AGNfitter path and catalog file name
agnfitter_path = 'C:\\Users\\PC\\AGNfitter\\'
catalog_file_name = 'catalog_example.txt'

# Construct the full path to the catalog file
catalog_file_path = os.path.join(agnfitter_path, catalog_file_name)

# Print the current working directory
print("Current Working Directory: ", os.getcwd())

# Print the constructed path to the catalog file
print("Catalog File Path: ", catalog_file_path)

# Check if the catalog file exists at the specified path
if os.path.isfile(catalog_file_path):
    print(f"Catalog file exists at: {catalog_file_path}")
else:
    print(f"Catalog file does not exist at: {catalog_file_path}")
# Out:
# Current Working Directory:  C:\Users\PC\AGNfitter
# Catalog File Path:  C:\Users\PC\AGNfitter\catalog_example.txt
# Catalog file exists at: C:\Users\PC\AGNfitter\catalog_example.txt

# %%
import subprocess
import os

# Define the path to the AGNfitter directory and settings file
agnfitter_path = 'C:\\Users\\PC\\AGNfitter\\'
settings_file = 'SETTINGS_AGNfitter.py'

# Check if the catalog file exists
catalog_file = os.path.join(agnfitter_path, 'catalog_example.txt')
if not os.path.isfile(catalog_file):
    print(f"Catalog file does not exist at: {catalog_file}")
else:
    # Command to run the AGNfitter script
    command = ['python', os.path.join(agnfitter_path, 'RUN_AGNfitter_multi.py'), settings_file]

    # Run the command and capture output
    try:
        result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
        print("AGNfitter script ran successfully.")
        print(result.stdout)
    except subprocess.CalledProcessError as e:
        print("Error running AGNfitter script:")
        print(e.stderr)
        print(e.stdout)
# Out:
# AGNfitter script ran successfully.
#
#              XXXX
# ___________ XXX _________________________________________________
#             XX
#             X
#             X                       AGNfitter
#          __ X __                    ---------
#      /**\   |   /**\
# ... (*** =  o  = ***) ...........................................
#      \**/__ | __\**/
#             X              Fitting SEDs of AGN and Galaxies
#             X             in a MCMC Approach
#            xx              (Calistro Rivera et al. 2016)
#           xx
# _______ xxx______________________________________________________
#      xxxx
#
# Catalog settings:  {'path': 'C:\\Users\\PC\\AGNfitter\\', 'filename': 'C:\\Users\\PC\\AGNfitter\\catalog_example.txt', 'filetype': 'ASCII', 'name': 0, 'redshift': 1, 'freq/wl_list': [2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74, 77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137, 140, 143, 146], 'use_central_wavelength': True, 'freq/wl_format': 'wavelength', 'freq/wl_unit': Unit("micron"), 'flux_in_magAB': False, 'flux_unit': <Quantity 0.001 Jy>, 'flux_list': [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147], 'fluxerr_list': [4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70, 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 103, 106, 109, 112, 115, 118, 121, 124, 127, 130, 133, 136, 139, 142, 145, 148], 'err+10%flux_moreflex': False, 'ndflag_bool': False, 'ndflag_list': 'list', 'workingpath': 'C:\\Users\\PC\\AGNfitter\\', 'output_folder': 'C:\\Users\\PC\\AGNfitter\\OUTPUT/'}
# Filters settings:  {'dict_zarray': array([], dtype=float64), 'path': 'models/FILTERS/', 'filterset': 'example_46datapointa', '4XMM_EP5': [True, 48], '4XMM_EP4': [True, 47], '4XMM_EP3': [True, 46], '4XMM_EP2': [True, 45], 'RAD_1_4GHz': [True, 44], 'RAD_5GHz': [True, 43], 'RAD_15GHz': [True, 42], 'SPIRE500': [True, 41], 'SPIRE350': [True, 40], 'SPIRE250': [True, 39], 'PACS160': [True, 38], 'PACS100': [True, 37], 'PACS70': [True, 36], 'M1': [True, 35], 'WISE4': [True, 34], 'WISE3': [True, 33], 'IRAC4': [True, 32], 'IRAC3': [True, 31], 'WISE2': [True, 30], 'IRAC2': [True, 29], 'IRAC1': [True, 28], 'WISE1': [True, 27], 'Ks_2mass': [True, 26], 'H_2mass': [True, 25], 'J_2mass': [True, 24], 'y_PS1_good': [True, 23], 'SKY_z': [True, 22], 'z': [True, 21], 'z_PS1': [True, 20], 'SKY_i': [True, 19], 'i_PS1': [True, 18], 'i': [True, 17], 'SKY_r': [True, 16], 'r_PS1': [True, 15], 'r': [True, 14], 'SWIFT_V': [True, 13], 'SKY_g': [True, 12], 'g_PS1': [True, 11], 'g': [True, 10], 'SWIFT_B': [True, 9], 'SKY_v': [True, 8], 'u': [True, 7], 'SKY_u': [True, 6], 'SWIFT_U': [True, 5], 'SWIFT_W1': [True, 4], 'GALEX_2500': [True, 3], 'SWIFT_M2': [True, 2], 'SWIFT_W2': [True, 1], 'GALEX_1500': [True, 0], 'add_filters': False, 'add_filters_dict': {'names': [], 'filenames': [], 'freq/wl_format': [], 'freq/wl_unit': [], 'description': []}}
# Models settings:  {'path': 'models/', 'modelset': 'modelsv1', 'GALAXY': 'BC03_metal', 'STARBURST': 'S17', 'BBB': 'THB21', 'TORUS': 'SKIRTOR_1P', 'XRAYS': False, 'RADIO': False, 'Blazar': 'None', 'PRIOR_energy_balance': 'Flexible', 'PRIOR_AGNfraction': True, 'PRIOR_midIR_UV': False, 'PRIOR_galaxy_only': False, 'turn_on_AGN': True}
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Option of one single dictionary for a whole catalogue is deprecated. Running "independent, -i" option.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  0
# - Sourcename:  Mrk493
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  1
# - Sourcename:  Mrk876
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 2 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 3 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 4 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 5 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 6 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 7 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 8 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 9 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 10 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 11 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 12 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 13 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 14 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 15 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 16 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 17 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 18 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 19 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 20 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 21 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 22 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 23 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 24 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 25 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
# ...
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 100 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 101 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 102 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 103 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 104 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 105 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 106 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 107 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 108 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 109 is out of bounds for the data array with size 2
# ======= : =======
# Process finished.

# %%
import subprocess
import os

# Define the paths
agnfitter_path = 'C:\\Users\\PC\\AGNfitter\\'
settings_file_name = 'SETTINGS_AGNfitter.py'
settings_file_path = os.path.join(agnfitter_path, settings_file_name)

# Print the settings file path
print("Settings File Path: ", settings_file_path)

# Command to run the AGNfitter script
command = ['python', os.path.join(agnfitter_path, 'RUN_AGNfitter_multi.py'), settings_file_path]

# Run the command and capture output
try:
    result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    print("AGNfitter script ran successfully.")
    print(result.stdout)
except subprocess.CalledProcessError as e:
    print("Error running AGNfitter script:")
    print(e.stderr)
    print(e.stdout)
# Out:
# Settings File Path:  C:\Users\PC\AGNfitter\SETTINGS_AGNfitter.py
# AGNfitter script ran successfully.
#
#              XXXX
# ___________ XXX _________________________________________________
#             XX
#             X
#             X                       AGNfitter
#          __ X __                    ---------
#      /**\   |   /**\
# ... (*** =  o  = ***) ...........................................
#      \**/__ | __\**/
#             X              Fitting SEDs of AGN and Galaxies
#             X             in a MCMC Approach
#            xx              (Calistro Rivera et al. 2016)
#           xx
# _______ xxx______________________________________________________
#      xxxx
#
# Catalog settings:  {'path': 'C:\\Users\\PC\\AGNfitter\\', 'filename': 'C:\\Users\\PC\\AGNfitter\\catalog_example.txt', 'filetype': 'ASCII', 'name': 0, 'redshift': 1, 'freq/wl_list': [2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74, 77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137, 140, 143, 146], 'use_central_wavelength': True, 'freq/wl_format': 'wavelength', 'freq/wl_unit': Unit("micron"), 'flux_in_magAB': False, 'flux_unit': <Quantity 0.001 Jy>, 'flux_list': [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147], 'fluxerr_list': [4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70, 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 103, 106, 109, 112, 115, 118, 121, 124, 127, 130, 133, 136, 139, 142, 145, 148], 'err+10%flux_moreflex': False, 'ndflag_bool': False, 'ndflag_list': 'list', 'workingpath': 'C:\\Users\\PC\\AGNfitter\\', 'output_folder': 'C:\\Users\\PC\\AGNfitter\\OUTPUT/'}
# Filters settings:  {'dict_zarray': array([], dtype=float64), 'path': 'models/FILTERS/', 'filterset': 'example_46datapointa', '4XMM_EP5': [True, 48], '4XMM_EP4': [True, 47], '4XMM_EP3': [True, 46], '4XMM_EP2': [True, 45], 'RAD_1_4GHz': [True, 44], 'RAD_5GHz': [True, 43], 'RAD_15GHz': [True, 42], 'SPIRE500': [True, 41], 'SPIRE350': [True, 40], 'SPIRE250': [True, 39], 'PACS160': [True, 38], 'PACS100': [True, 37], 'PACS70': [True, 36], 'M1': [True, 35], 'WISE4': [True, 34], 'WISE3': [True, 33], 'IRAC4': [True, 32], 'IRAC3': [True, 31], 'WISE2': [True, 30], 'IRAC2': [True, 29], 'IRAC1': [True, 28], 'WISE1': [True, 27], 'Ks_2mass': [True, 26], 'H_2mass': [True, 25], 'J_2mass': [True, 24], 'y_PS1_good': [True, 23], 'SKY_z': [True, 22], 'z': [True, 21], 'z_PS1': [True, 20], 'SKY_i': [True, 19], 'i_PS1': [True, 18], 'i': [True, 17], 'SKY_r': [True, 16], 'r_PS1': [True, 15], 'r': [True, 14], 'SWIFT_V': [True, 13], 'SKY_g': [True, 12], 'g_PS1': [True, 11], 'g': [True, 10], 'SWIFT_B': [True, 9], 'SKY_v': [True, 8], 'u': [True, 7], 'SKY_u': [True, 6], 'SWIFT_U': [True, 5], 'SWIFT_W1': [True, 4], 'GALEX_2500': [True, 3], 'SWIFT_M2': [True, 2], 'SWIFT_W2': [True, 1], 'GALEX_1500': [True, 0], 'add_filters': False, 'add_filters_dict': {'names': [], 'filenames': [], 'freq/wl_format': [], 'freq/wl_unit': [], 'description': []}}
# Models settings:  {'path': 'models/', 'modelset': 'modelsv1', 'GALAXY': 'BC03_metal', 'STARBURST': 'S17', 'BBB': 'THB21', 'TORUS': 'SKIRTOR_1P', 'XRAYS': False, 'RADIO': False, 'Blazar': 'None', 'PRIOR_energy_balance': 'Flexible', 'PRIOR_AGNfraction': True, 'PRIOR_midIR_UV': False, 'PRIOR_galaxy_only': False, 'turn_on_AGN': True}
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Option of one single dictionary for a whole catalogue is deprecated. Running "independent, -i" option.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  0
# - Sourcename:  Mrk493
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  1
# - Sourcename:  Mrk876
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 2 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 3 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 4 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 5 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 6 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 7 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 8 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 9 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 10 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 11 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 12 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 13 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 14 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 15 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 16 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 17 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 18 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 19 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 20 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 21 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 22 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 23 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 24 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 25 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
# ...
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 100 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 101 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 102 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 103 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 104 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 105 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 106 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 107 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 108 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 109 is out of bounds for the data array with size 2
# ======= : =======
# Process finished.

# %%
import subprocess
import os

# Define the paths
agnfitter_path = 'C:\\Users\\PC\\AGNfitter\\'
settings_file_name = 'SETTINGS_AGNfitter.py'
settings_file_path = os.path.join(agnfitter_path, settings_file_name)

# Print the settings file path
print("Settings File Path: ", settings_file_path)

# Command to run the AGNfitter script
command = ['python', os.path.join(agnfitter_path, 'RUN_AGNfitter_multi.py'), settings_file_path]

# Run the command and capture output
try:
    result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    print("AGNfitter script ran successfully.")
    print(result.stdout)
except subprocess.CalledProcessError as e:
    print("Error running AGNfitter script:")
    print(e.stderr)
    print(e.stdout)
# Out:
# Settings File Path:  C:\Users\PC\AGNfitter\SETTINGS_AGNfitter.py
# AGNfitter script ran successfully.
#
#              XXXX
# ___________ XXX _________________________________________________
#             XX
#             X
#             X                       AGNfitter
#          __ X __                    ---------
#      /**\   |   /**\
# ... (*** =  o  = ***) ...........................................
#      \**/__ | __\**/
#             X              Fitting SEDs of AGN and Galaxies
#             X             in a MCMC Approach
#            xx              (Calistro Rivera et al. 2016)
#           xx
# _______ xxx______________________________________________________
#      xxxx
#
# Catalog settings:  {'path': 'C:\\Users\\PC\\AGNfitter\\', 'filename': 'C:\\Users\\PC\\AGNfitter\\catalog_example.txt', 'filetype': 'ASCII', 'name': 0, 'redshift': 1, 'freq/wl_list': [2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74, 77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137, 140, 143, 146], 'use_central_wavelength': True, 'freq/wl_format': 'wavelength', 'freq/wl_unit': Unit("micron"), 'flux_in_magAB': False, 'flux_unit': <Quantity 0.001 Jy>, 'flux_list': [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147], 'fluxerr_list': [4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70, 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 103, 106, 109, 112, 115, 118, 121, 124, 127, 130, 133, 136, 139, 142, 145, 148], 'err+10%flux_moreflex': False, 'ndflag_bool': False, 'ndflag_list': 'list', 'workingpath': 'C:\\Users\\PC\\AGNfitter\\', 'output_folder': 'C:\\Users\\PC\\AGNfitter\\OUTPUT/'}
# Filters settings:  {'dict_zarray': array([], dtype=float64), 'path': 'models/FILTERS/', 'filterset': 'example_46datapointa', '4XMM_EP5': [True, 48], '4XMM_EP4': [True, 47], '4XMM_EP3': [True, 46], '4XMM_EP2': [True, 45], 'RAD_1_4GHz': [True, 44], 'RAD_5GHz': [True, 43], 'RAD_15GHz': [True, 42], 'SPIRE500': [True, 41], 'SPIRE350': [True, 40], 'SPIRE250': [True, 39], 'PACS160': [True, 38], 'PACS100': [True, 37], 'PACS70': [True, 36], 'M1': [True, 35], 'WISE4': [True, 34], 'WISE3': [True, 33], 'IRAC4': [True, 32], 'IRAC3': [True, 31], 'WISE2': [True, 30], 'IRAC2': [True, 29], 'IRAC1': [True, 28], 'WISE1': [True, 27], 'Ks_2mass': [True, 26], 'H_2mass': [True, 25], 'J_2mass': [True, 24], 'y_PS1_good': [True, 23], 'SKY_z': [True, 22], 'z': [True, 21], 'z_PS1': [True, 20], 'SKY_i': [True, 19], 'i_PS1': [True, 18], 'i': [True, 17], 'SKY_r': [True, 16], 'r_PS1': [True, 15], 'r': [True, 14], 'SWIFT_V': [True, 13], 'SKY_g': [True, 12], 'g_PS1': [True, 11], 'g': [True, 10], 'SWIFT_B': [True, 9], 'SKY_v': [True, 8], 'u': [True, 7], 'SKY_u': [True, 6], 'SWIFT_U': [True, 5], 'SWIFT_W1': [True, 4], 'GALEX_2500': [True, 3], 'SWIFT_M2': [True, 2], 'SWIFT_W2': [True, 1], 'GALEX_1500': [True, 0], 'add_filters': False, 'add_filters_dict': {'names': [], 'filenames': [], 'freq/wl_format': [], 'freq/wl_unit': [], 'description': []}}
# Models settings:  {'path': 'models/', 'modelset': 'modelsv1', 'GALAXY': 'BC03_metal', 'STARBURST': 'S17', 'BBB': 'THB21', 'TORUS': 'SKIRTOR_1P', 'XRAYS': False, 'RADIO': False, 'Blazar': 'None', 'PRIOR_energy_balance': 'Flexible', 'PRIOR_AGNfraction': True, 'PRIOR_midIR_UV': False, 'PRIOR_galaxy_only': False, 'turn_on_AGN': True}
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Option of one single dictionary for a whole catalogue is deprecated. Running "independent, -i" option.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  0
# - Sourcename:  Mrk493
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  1
# - Sourcename:  Mrk876
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 2 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 3 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 4 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 5 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 6 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 7 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 8 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 9 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 10 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 11 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 12 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 13 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 14 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 15 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 16 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 17 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 18 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 19 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 20 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 21 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 22 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 23 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 24 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 25 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
# ...
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 100 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 101 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 102 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 103 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 104 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 105 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 106 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 107 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 108 is out of bounds for the data array with size 2
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
# Error: Line index 109 is out of bounds for the data array with size 2
# ======= : =======
# Process finished.

# %%
import os

agnfitter_path = 'C:\\Users\\PC\\AGNfitter\\'
data_agnfitter_file = os.path.join(agnfitter_path, 'functions', 'DATA_AGNfitter.py')

# Read the content of the file
with open(data_agnfitter_file, 'r') as file:
    file_content = file.read()

# Replace np.float with np.float64
updated_content = file_content.replace('np.float', 'np.float64')

# Write the updated content back to the file
with open(data_agnfitter_file, 'w') as file:
    file.write(updated_content)

print("Updated np.float to np.float64 in DATA_AGNfitter.py")
# Out:
# Updated np.float to np.float64 in DATA_AGNfitter.py

# %%
import subprocess
import os

# Define the paths
agnfitter_path = 'C:\\Users\\PC\\AGNfitter\\'
settings_file_name = 'SETTINGS_AGNfitter.py'
settings_file_path = os.path.join(agnfitter_path, settings_file_name)

# Print the settings file path
print("Settings File Path: ", settings_file_path)

# Command to run the AGNfitter script
command = ['python', os.path.join(agnfitter_path, 'RUN_AGNfitter_multi.py'), settings_file_path]

# Run the command and capture output
try:
    result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    print("AGNfitter script ran successfully.")
    print(result.stdout)
except subprocess.CalledProcessError as e:
    print("Error running AGNfitter script:")
    print(e.stderr)
    print(e.stdout)
# Out:
# Settings File Path:  C:\Users\PC\AGNfitter\SETTINGS_AGNfitter.py
# Error running AGNfitter script:
# Traceback (most recent call last):
#   File "C:\Users\PC\AGNfitter\RUN_AGNfitter_multi.py", line 301, in <module>
#     data_ALL.PROPS()
#   File "C:\Users\PC\AGNfitter\functions\DATA_AGNfitter.py", line 103, in PROPS
#     np.array(column.iloc[:, self.cat['flux_list']]).astype(np.float6464) * self.cat['flux_unit']
#                                                            ^^^^^^^^^^^^
#   File "C:\Users\PC\anaconda3\Lib\site-packages\numpy\__init__.py", line 320, in __getattr__
#     raise AttributeError("module {!r} has no attribute "
# AttributeError: module 'numpy' has no attribute 'float6464'. Did you mean: 'float64'?
#
#
#              XXXX
# ___________ XXX _________________________________________________
#             XX
#             X
#             X                       AGNfitter
#          __ X __                    ---------
#      /**\   |   /**\
# ... (*** =  o  = ***) ...........................................
#      \**/__ | __\**/
#             X              Fitting SEDs of AGN and Galaxies
#             X             in a MCMC Approach
#            xx              (Calistro Rivera et al. 2016)
#           xx
# _______ xxx______________________________________________________
#      xxxx
#
# Catalog settings:  {'path': 'C:\\Users\\PC\\AGNfitter\\', 'filename': 'C:\\Users\\PC\\AGNfitter\\catalog_example.txt', 'filetype': 'ASCII', 'name': 0, 'redshift': 1, 'freq/wl_list': [2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74, 77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137, 140, 143, 146], 'use_central_wavelength': True, 'freq/wl_format': 'wavelength', 'freq/wl_unit': Unit("micron"), 'flux_in_magAB': False, 'flux_unit': <Quantity 0.001 Jy>, 'flux_list': [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147], 'fluxerr_list': [4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70, 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 103, 106, 109, 112, 115, 118, 121, 124, 127, 130, 133, 136, 139, 142, 145, 148], 'err+10%flux_moreflex': False, 'ndflag_bool': False, 'ndflag_list': 'list', 'workingpath': 'C:\\Users\\PC\\AGNfitter\\', 'output_folder': 'C:\\Users\\PC\\AGNfitter\\OUTPUT/'}
# Filters settings:  {'dict_zarray': array([], dtype=float64), 'path': 'models/FILTERS/', 'filterset': 'example_46datapointa', '4XMM_EP5': [True, 48], '4XMM_EP4': [True, 47], '4XMM_EP3': [True, 46], '4XMM_EP2': [True, 45], 'RAD_1_4GHz': [True, 44], 'RAD_5GHz': [True, 43], 'RAD_15GHz': [True, 42], 'SPIRE500': [True, 41], 'SPIRE350': [True, 40], 'SPIRE250': [True, 39], 'PACS160': [True, 38], 'PACS100': [True, 37], 'PACS70': [True, 36], 'M1': [True, 35], 'WISE4': [True, 34], 'WISE3': [True, 33], 'IRAC4': [True, 32], 'IRAC3': [True, 31], 'WISE2': [True, 30], 'IRAC2': [True, 29], 'IRAC1': [True, 28], 'WISE1': [True, 27], 'Ks_2mass': [True, 26], 'H_2mass': [True, 25], 'J_2mass': [True, 24], 'y_PS1_good': [True, 23], 'SKY_z': [True, 22], 'z': [True, 21], 'z_PS1': [True, 20], 'SKY_i': [True, 19], 'i_PS1': [True, 18], 'i': [True, 17], 'SKY_r': [True, 16], 'r_PS1': [True, 15], 'r': [True, 14], 'SWIFT_V': [True, 13], 'SKY_g': [True, 12], 'g_PS1': [True, 11], 'g': [True, 10], 'SWIFT_B': [True, 9], 'SKY_v': [True, 8], 'u': [True, 7], 'SKY_u': [True, 6], 'SWIFT_U': [True, 5], 'SWIFT_W1': [True, 4], 'GALEX_2500': [True, 3], 'SWIFT_M2': [True, 2], 'SWIFT_W2': [True, 1], 'GALEX_1500': [True, 0], 'add_filters': False, 'add_filters_dict': {'names': [], 'filenames': [], 'freq/wl_format': [], 'freq/wl_unit': [], 'description': []}}
# Models settings:  {'path': 'models/', 'modelset': 'modelsv1', 'GALAXY': 'BC03_metal', 'STARBURST': 'S17', 'BBB': 'THB21', 'TORUS': 'SKIRTOR_1P', 'XRAYS': False, 'RADIO': False, 'Blazar': 'None', 'PRIOR_energy_balance': 'Flexible', 'PRIOR_AGNfraction': True, 'PRIOR_midIR_UV': False, 'PRIOR_galaxy_only': False, 'turn_on_AGN': True}
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}

# %%
import subprocess
import os

# Define the paths
agnfitter_path = 'C:\\Users\\PC\\AGNfitter\\'
settings_file_name = 'SETTINGS_AGNfitter.py'
settings_file_path = os.path.join(agnfitter_path, settings_file_name)

# Print the settings file path
print("Settings File Path: ", settings_file_path)

# Command to run the AGNfitter script
command = ['python', os.path.join(agnfitter_path, 'RUN_AGNfitter_multi.py'), settings_file_path]

# Run the command and capture output
try:
    result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    print("AGNfitter script ran successfully.")
    print(result.stdout)
except subprocess.CalledProcessError as e:
    print("Error running AGNfitter script:")
    print(e.stderr)
    print(e.stdout)
# Out:
# Settings File Path:  C:\Users\PC\AGNfitter\SETTINGS_AGNfitter.py
# Error running AGNfitter script:
# Traceback (most recent call last):
#   File "C:\Users\PC\AGNfitter\RUN_AGNfitter_multi.py", line 301, in <module>
#     data_ALL.PROPS()
#   File "C:\Users\PC\AGNfitter\functions\DATA_AGNfitter.py", line 103, in PROPS
#     np.array(column.iloc[:, self.cat['flux_list']]).astype(np.float6464) * self.cat['flux_unit']
#                                                            ^^^^^^^^^^^^
#   File "C:\Users\PC\anaconda3\Lib\site-packages\numpy\__init__.py", line 320, in __getattr__
#     raise AttributeError("module {!r} has no attribute "
# AttributeError: module 'numpy' has no attribute 'float6464'. Did you mean: 'float64'?
#
#
#              XXXX
# ___________ XXX _________________________________________________
#             XX
#             X
#             X                       AGNfitter
#          __ X __                    ---------
#      /**\   |   /**\
# ... (*** =  o  = ***) ...........................................
#      \**/__ | __\**/
#             X              Fitting SEDs of AGN and Galaxies
#             X             in a MCMC Approach
#            xx              (Calistro Rivera et al. 2016)
#           xx
# _______ xxx______________________________________________________
#      xxxx
#
# Catalog settings:  {'path': 'C:\\Users\\PC\\AGNfitter\\', 'filename': 'C:\\Users\\PC\\AGNfitter\\catalog_example.txt', 'filetype': 'ASCII', 'name': 0, 'redshift': 1, 'freq/wl_list': [2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74, 77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137, 140, 143, 146], 'use_central_wavelength': True, 'freq/wl_format': 'wavelength', 'freq/wl_unit': Unit("micron"), 'flux_in_magAB': False, 'flux_unit': <Quantity 0.001 Jy>, 'flux_list': [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147], 'fluxerr_list': [4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70, 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 103, 106, 109, 112, 115, 118, 121, 124, 127, 130, 133, 136, 139, 142, 145, 148], 'err+10%flux_moreflex': False, 'ndflag_bool': False, 'ndflag_list': 'list', 'workingpath': 'C:\\Users\\PC\\AGNfitter\\', 'output_folder': 'C:\\Users\\PC\\AGNfitter\\OUTPUT/'}
# Filters settings:  {'dict_zarray': array([], dtype=float64), 'path': 'models/FILTERS/', 'filterset': 'example_46datapointa', '4XMM_EP5': [True, 48], '4XMM_EP4': [True, 47], '4XMM_EP3': [True, 46], '4XMM_EP2': [True, 45], 'RAD_1_4GHz': [True, 44], 'RAD_5GHz': [True, 43], 'RAD_15GHz': [True, 42], 'SPIRE500': [True, 41], 'SPIRE350': [True, 40], 'SPIRE250': [True, 39], 'PACS160': [True, 38], 'PACS100': [True, 37], 'PACS70': [True, 36], 'M1': [True, 35], 'WISE4': [True, 34], 'WISE3': [True, 33], 'IRAC4': [True, 32], 'IRAC3': [True, 31], 'WISE2': [True, 30], 'IRAC2': [True, 29], 'IRAC1': [True, 28], 'WISE1': [True, 27], 'Ks_2mass': [True, 26], 'H_2mass': [True, 25], 'J_2mass': [True, 24], 'y_PS1_good': [True, 23], 'SKY_z': [True, 22], 'z': [True, 21], 'z_PS1': [True, 20], 'SKY_i': [True, 19], 'i_PS1': [True, 18], 'i': [True, 17], 'SKY_r': [True, 16], 'r_PS1': [True, 15], 'r': [True, 14], 'SWIFT_V': [True, 13], 'SKY_g': [True, 12], 'g_PS1': [True, 11], 'g': [True, 10], 'SWIFT_B': [True, 9], 'SKY_v': [True, 8], 'u': [True, 7], 'SKY_u': [True, 6], 'SWIFT_U': [True, 5], 'SWIFT_W1': [True, 4], 'GALEX_2500': [True, 3], 'SWIFT_M2': [True, 2], 'SWIFT_W2': [True, 1], 'GALEX_1500': [True, 0], 'add_filters': False, 'add_filters_dict': {'names': [], 'filenames': [], 'freq/wl_format': [], 'freq/wl_unit': [], 'description': []}}
# Models settings:  {'path': 'models/', 'modelset': 'modelsv1', 'GALAXY': 'BC03_metal', 'STARBURST': 'S17', 'BBB': 'THB21', 'TORUS': 'SKIRTOR_1P', 'XRAYS': False, 'RADIO': False, 'Blazar': 'None', 'PRIOR_energy_balance': 'Flexible', 'PRIOR_AGNfraction': True, 'PRIOR_midIR_UV': False, 'PRIOR_galaxy_only': False, 'turn_on_AGN': True}
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}

# %%
import os

# Define the required directory
required_directory = 'C:\\Users\\PC\\AGNfitter\\OUTPUT\\Mrk493'

# Create the directory if it does not exist
if not os.path.exists(required_directory):
    os.makedirs(required_directory)
    print(f"Created directory: {required_directory}")
else:
    print(f"Directory already exists: {required_directory}")
# Out:
# Directory already exists: C:\Users\PC\AGNfitter\OUTPUT\Mrk493

# %%
import os
import subprocess

# Define the paths
agnfitter_path = 'C:\\Users\\PC\\AGNfitter\\'
settings_file_name = 'SETTINGS_AGNfitter.py'
settings_file_path = os.path.join(agnfitter_path, settings_file_name)

# Create the required directory
required_directory = os.path.join(agnfitter_path, 'OUTPUT', 'Mrk493')
if not os.path.exists(required_directory):
    os.makedirs(required_directory)
    print(f"Created directory: {required_directory}")
else:
    print(f"Directory already exists: {required_directory}")

# Print the settings file path
print("Settings File Path: ", settings_file_path)

# Command to run the AGNfitter script
command = ['python', os.path.join(agnfitter_path, 'RUN_AGNfitter_multi.py'), settings_file_path]

# Run the command and capture output
try:
    result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    print("AGNfitter script ran successfully.")
    print(result.stdout)
except subprocess.CalledProcessError as e:
    print("Error running AGNfitter script:")
    print(e.stderr)
    print(e.stdout)
# Out:
# Directory already exists: C:\Users\PC\AGNfitter\OUTPUT\Mrk493
# Settings File Path:  C:\Users\PC\AGNfitter\SETTINGS_AGNfitter.py
# Error running AGNfitter script:
# Traceback (most recent call last):
#   File "C:\Users\PC\AGNfitter\RUN_AGNfitter_multi.py", line 301, in <module>
#     data_ALL.PROPS()
#   File "C:\Users\PC\AGNfitter\functions\DATA_AGNfitter.py", line 103, in PROPS
#     np.array(column.iloc[:, self.cat['flux_list']]).astype(np.float6464) * self.cat['flux_unit']
#                                                            ^^^^^^^^^^^^
#   File "C:\Users\PC\anaconda3\Lib\site-packages\numpy\__init__.py", line 320, in __getattr__
#     raise AttributeError("module {!r} has no attribute "
# AttributeError: module 'numpy' has no attribute 'float6464'. Did you mean: 'float64'?
#
#
#              XXXX
# ___________ XXX _________________________________________________
#             XX
#             X
#             X                       AGNfitter
#          __ X __                    ---------
#      /**\   |   /**\
# ... (*** =  o  = ***) ...........................................
#      \**/__ | __\**/
#             X              Fitting SEDs of AGN and Galaxies
#             X             in a MCMC Approach
#            xx              (Calistro Rivera et al. 2016)
#           xx
# _______ xxx______________________________________________________
#      xxxx
#
# Catalog settings:  {'path': 'C:\\Users\\PC\\AGNfitter\\', 'filename': 'C:\\Users\\PC\\AGNfitter\\catalog_example.txt', 'filetype': 'ASCII', 'name': 0, 'redshift': 1, 'freq/wl_list': [2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74, 77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137, 140, 143, 146], 'use_central_wavelength': True, 'freq/wl_format': 'wavelength', 'freq/wl_unit': Unit("micron"), 'flux_in_magAB': False, 'flux_unit': <Quantity 0.001 Jy>, 'flux_list': [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147], 'fluxerr_list': [4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70, 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 103, 106, 109, 112, 115, 118, 121, 124, 127, 130, 133, 136, 139, 142, 145, 148], 'err+10%flux_moreflex': False, 'ndflag_bool': False, 'ndflag_list': 'list', 'workingpath': 'C:\\Users\\PC\\AGNfitter\\', 'output_folder': 'C:\\Users\\PC\\AGNfitter\\OUTPUT/'}
# Filters settings:  {'dict_zarray': array([], dtype=float64), 'path': 'models/FILTERS/', 'filterset': 'example_46datapointa', '4XMM_EP5': [True, 48], '4XMM_EP4': [True, 47], '4XMM_EP3': [True, 46], '4XMM_EP2': [True, 45], 'RAD_1_4GHz': [True, 44], 'RAD_5GHz': [True, 43], 'RAD_15GHz': [True, 42], 'SPIRE500': [True, 41], 'SPIRE350': [True, 40], 'SPIRE250': [True, 39], 'PACS160': [True, 38], 'PACS100': [True, 37], 'PACS70': [True, 36], 'M1': [True, 35], 'WISE4': [True, 34], 'WISE3': [True, 33], 'IRAC4': [True, 32], 'IRAC3': [True, 31], 'WISE2': [True, 30], 'IRAC2': [True, 29], 'IRAC1': [True, 28], 'WISE1': [True, 27], 'Ks_2mass': [True, 26], 'H_2mass': [True, 25], 'J_2mass': [True, 24], 'y_PS1_good': [True, 23], 'SKY_z': [True, 22], 'z': [True, 21], 'z_PS1': [True, 20], 'SKY_i': [True, 19], 'i_PS1': [True, 18], 'i': [True, 17], 'SKY_r': [True, 16], 'r_PS1': [True, 15], 'r': [True, 14], 'SWIFT_V': [True, 13], 'SKY_g': [True, 12], 'g_PS1': [True, 11], 'g': [True, 10], 'SWIFT_B': [True, 9], 'SKY_v': [True, 8], 'u': [True, 7], 'SKY_u': [True, 6], 'SWIFT_U': [True, 5], 'SWIFT_W1': [True, 4], 'GALEX_2500': [True, 3], 'SWIFT_M2': [True, 2], 'SWIFT_W2': [True, 1], 'GALEX_1500': [True, 0], 'add_filters': False, 'add_filters_dict': {'names': [], 'filenames': [], 'freq/wl_format': [], 'freq/wl_unit': [], 'description': []}}
# Models settings:  {'path': 'models/', 'modelset': 'modelsv1', 'GALAXY': 'BC03_metal', 'STARBURST': 'S17', 'BBB': 'THB21', 'TORUS': 'SKIRTOR_1P', 'XRAYS': False, 'RADIO': False, 'Blazar': 'None', 'PRIOR_energy_balance': 'Flexible', 'PRIOR_AGNfraction': True, 'PRIOR_midIR_UV': False, 'PRIOR_galaxy_only': False, 'turn_on_AGN': True}
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}

# %%
import os
import subprocess
import matplotlib.pyplot as plt

# Disable LaTeX
plt.rcParams['text.usetex'] = False

# Optionally, configure the font to avoid using LaTeX-style fonts
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Arial']

# Define the paths
agnfitter_path = 'C:\\Users\\PC\\AGNfitter\\'
settings_file_name = 'SETTINGS_AGNfitter.py'
settings_file_path = os.path.join(agnfitter_path, settings_file_name)

# Create the required directory
required_directory = os.path.join(agnfitter_path, 'OUTPUT', 'Mrk493')
if not os.path.exists(required_directory):
    os.makedirs(required_directory)
    print(f"Created directory: {required_directory}")
else:
    print(f"Directory already exists: {required_directory}")

# Print the settings file path
print("Settings File Path: ", settings_file_path)

# Command to run the AGNfitter script
command = ['python', os.path.join(agnfitter_path, 'RUN_AGNfitter_multi.py'), settings_file_path]

# Run the command and capture output
try:
    result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    print("AGNfitter script ran successfully.")
    print(result.stdout)
except subprocess.CalledProcessError as e:
    print("Error running AGNfitter script:")
    print(e.stderr)
    print(e.stdout)
# Out:
# Directory already exists: C:\Users\PC\AGNfitter\OUTPUT\Mrk493
# Settings File Path:  C:\Users\PC\AGNfitter\SETTINGS_AGNfitter.py
# Error running AGNfitter script:
# Traceback (most recent call last):
#   File "C:\Users\PC\AGNfitter\RUN_AGNfitter_multi.py", line 301, in <module>
#     data_ALL.PROPS()
#   File "C:\Users\PC\AGNfitter\functions\DATA_AGNfitter.py", line 103, in PROPS
#     np.array(column.iloc[:, self.cat['flux_list']]).astype(np.float6464) * self.cat['flux_unit']
#                                                            ^^^^^^^^^^^^
#   File "C:\Users\PC\anaconda3\Lib\site-packages\numpy\__init__.py", line 320, in __getattr__
#     raise AttributeError("module {!r} has no attribute "
# AttributeError: module 'numpy' has no attribute 'float6464'. Did you mean: 'float64'?
#
#
#              XXXX
# ___________ XXX _________________________________________________
#             XX
#             X
#             X                       AGNfitter
#          __ X __                    ---------
#      /**\   |   /**\
# ... (*** =  o  = ***) ...........................................
#      \**/__ | __\**/
#             X              Fitting SEDs of AGN and Galaxies
#             X             in a MCMC Approach
#            xx              (Calistro Rivera et al. 2016)
#           xx
# _______ xxx______________________________________________________
#      xxxx
#
# Catalog settings:  {'path': 'C:\\Users\\PC\\AGNfitter\\', 'filename': 'C:\\Users\\PC\\AGNfitter\\catalog_example.txt', 'filetype': 'ASCII', 'name': 0, 'redshift': 1, 'freq/wl_list': [2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74, 77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137, 140, 143, 146], 'use_central_wavelength': True, 'freq/wl_format': 'wavelength', 'freq/wl_unit': Unit("micron"), 'flux_in_magAB': False, 'flux_unit': <Quantity 0.001 Jy>, 'flux_list': [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147], 'fluxerr_list': [4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70, 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 103, 106, 109, 112, 115, 118, 121, 124, 127, 130, 133, 136, 139, 142, 145, 148], 'err+10%flux_moreflex': False, 'ndflag_bool': False, 'ndflag_list': 'list', 'workingpath': 'C:\\Users\\PC\\AGNfitter\\', 'output_folder': 'C:\\Users\\PC\\AGNfitter\\OUTPUT/'}
# Filters settings:  {'dict_zarray': array([], dtype=float64), 'path': 'models/FILTERS/', 'filterset': 'example_46datapointa', '4XMM_EP5': [True, 48], '4XMM_EP4': [True, 47], '4XMM_EP3': [True, 46], '4XMM_EP2': [True, 45], 'RAD_1_4GHz': [True, 44], 'RAD_5GHz': [True, 43], 'RAD_15GHz': [True, 42], 'SPIRE500': [True, 41], 'SPIRE350': [True, 40], 'SPIRE250': [True, 39], 'PACS160': [True, 38], 'PACS100': [True, 37], 'PACS70': [True, 36], 'M1': [True, 35], 'WISE4': [True, 34], 'WISE3': [True, 33], 'IRAC4': [True, 32], 'IRAC3': [True, 31], 'WISE2': [True, 30], 'IRAC2': [True, 29], 'IRAC1': [True, 28], 'WISE1': [True, 27], 'Ks_2mass': [True, 26], 'H_2mass': [True, 25], 'J_2mass': [True, 24], 'y_PS1_good': [True, 23], 'SKY_z': [True, 22], 'z': [True, 21], 'z_PS1': [True, 20], 'SKY_i': [True, 19], 'i_PS1': [True, 18], 'i': [True, 17], 'SKY_r': [True, 16], 'r_PS1': [True, 15], 'r': [True, 14], 'SWIFT_V': [True, 13], 'SKY_g': [True, 12], 'g_PS1': [True, 11], 'g': [True, 10], 'SWIFT_B': [True, 9], 'SKY_v': [True, 8], 'u': [True, 7], 'SKY_u': [True, 6], 'SWIFT_U': [True, 5], 'SWIFT_W1': [True, 4], 'GALEX_2500': [True, 3], 'SWIFT_M2': [True, 2], 'SWIFT_W2': [True, 1], 'GALEX_1500': [True, 0], 'add_filters': False, 'add_filters_dict': {'names': [], 'filenames': [], 'freq/wl_format': [], 'freq/wl_unit': [], 'description': []}}
# Models settings:  {'path': 'models/', 'modelset': 'modelsv1', 'GALAXY': 'BC03_metal', 'STARBURST': 'S17', 'BBB': 'THB21', 'TORUS': 'SKIRTOR_1P', 'XRAYS': False, 'RADIO': False, 'Blazar': 'None', 'PRIOR_energy_balance': 'Flexible', 'PRIOR_AGNfraction': True, 'PRIOR_midIR_UV': False, 'PRIOR_galaxy_only': False, 'turn_on_AGN': True}
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}

# %%
import os
import subprocess
import matplotlib.pyplot as plt

# Disable LaTeX
plt.rcParams['text.usetex'] = False

# Optionally, configure the font to avoid using LaTeX-style fonts
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Arial']

# Define the paths
agnfitter_path = 'C:\\Users\\PC\\AGNfitter\\'
settings_file_name = 'SETTINGS_AGNfitter.py'
settings_file_path = os.path.join(agnfitter_path, settings_file_name)

# Create the required directory
required_directory = os.path.join(agnfitter_path, 'OUTPUT', 'Mrk493')
if not os.path.exists(required_directory):
    os.makedirs(required_directory)
    print(f"Created directory: {required_directory}")
else:
    print(f"Directory already exists: {required_directory}")

# Print the settings file path
print("Settings File Path: ", settings_file_path)

# Command to run the AGNfitter script
command = ['python', os.path.join(agnfitter_path, 'RUN_AGNfitter_multi.py'), settings_file_path]

# Run the command and capture output
try:
    result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    print("AGNfitter script ran successfully.")
    print(result.stdout)
except subprocess.CalledProcessError as e:
    print("Error running AGNfitter script:")
    print(e.stderr)
    print(e.stdout)
# Out:
# Directory already exists: C:\Users\PC\AGNfitter\OUTPUT\Mrk493
# Settings File Path:  C:\Users\PC\AGNfitter\SETTINGS_AGNfitter.py
# Error running AGNfitter script:
# Traceback (most recent call last):
#   File "C:\Users\PC\AGNfitter\RUN_AGNfitter_multi.py", line 301, in <module>
#     data_ALL.PROPS()
#   File "C:\Users\PC\AGNfitter\functions\DATA_AGNfitter.py", line 103, in PROPS
#     np.array(column.iloc[:, self.cat['flux_list']]).astype(np.float6464) * self.cat['flux_unit']
#                                                            ^^^^^^^^^^^^
#   File "C:\Users\PC\anaconda3\Lib\site-packages\numpy\__init__.py", line 320, in __getattr__
#     raise AttributeError("module {!r} has no attribute "
# AttributeError: module 'numpy' has no attribute 'float6464'. Did you mean: 'float64'?
#
#
#              XXXX
# ___________ XXX _________________________________________________
#             XX
#             X
#             X                       AGNfitter
#          __ X __                    ---------
#      /**\   |   /**\
# ... (*** =  o  = ***) ...........................................
#      \**/__ | __\**/
#             X              Fitting SEDs of AGN and Galaxies
#             X             in a MCMC Approach
#            xx              (Calistro Rivera et al. 2016)
#           xx
# _______ xxx______________________________________________________
#      xxxx
#
# Catalog settings:  {'path': 'C:\\Users\\PC\\AGNfitter\\', 'filename': 'C:\\Users\\PC\\AGNfitter\\catalog_example.txt', 'filetype': 'ASCII', 'name': 0, 'redshift': 1, 'freq/wl_list': [2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74, 77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137, 140, 143, 146], 'use_central_wavelength': True, 'freq/wl_format': 'wavelength', 'freq/wl_unit': Unit("micron"), 'flux_in_magAB': False, 'flux_unit': <Quantity 0.001 Jy>, 'flux_list': [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147], 'fluxerr_list': [4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70, 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 103, 106, 109, 112, 115, 118, 121, 124, 127, 130, 133, 136, 139, 142, 145, 148], 'err+10%flux_moreflex': False, 'ndflag_bool': False, 'ndflag_list': 'list', 'workingpath': 'C:\\Users\\PC\\AGNfitter\\', 'output_folder': 'C:\\Users\\PC\\AGNfitter\\OUTPUT/'}
# Filters settings:  {'dict_zarray': array([], dtype=float64), 'path': 'models/FILTERS/', 'filterset': 'example_46datapointa', '4XMM_EP5': [True, 48], '4XMM_EP4': [True, 47], '4XMM_EP3': [True, 46], '4XMM_EP2': [True, 45], 'RAD_1_4GHz': [True, 44], 'RAD_5GHz': [True, 43], 'RAD_15GHz': [True, 42], 'SPIRE500': [True, 41], 'SPIRE350': [True, 40], 'SPIRE250': [True, 39], 'PACS160': [True, 38], 'PACS100': [True, 37], 'PACS70': [True, 36], 'M1': [True, 35], 'WISE4': [True, 34], 'WISE3': [True, 33], 'IRAC4': [True, 32], 'IRAC3': [True, 31], 'WISE2': [True, 30], 'IRAC2': [True, 29], 'IRAC1': [True, 28], 'WISE1': [True, 27], 'Ks_2mass': [True, 26], 'H_2mass': [True, 25], 'J_2mass': [True, 24], 'y_PS1_good': [True, 23], 'SKY_z': [True, 22], 'z': [True, 21], 'z_PS1': [True, 20], 'SKY_i': [True, 19], 'i_PS1': [True, 18], 'i': [True, 17], 'SKY_r': [True, 16], 'r_PS1': [True, 15], 'r': [True, 14], 'SWIFT_V': [True, 13], 'SKY_g': [True, 12], 'g_PS1': [True, 11], 'g': [True, 10], 'SWIFT_B': [True, 9], 'SKY_v': [True, 8], 'u': [True, 7], 'SKY_u': [True, 6], 'SWIFT_U': [True, 5], 'SWIFT_W1': [True, 4], 'GALEX_2500': [True, 3], 'SWIFT_M2': [True, 2], 'SWIFT_W2': [True, 1], 'GALEX_1500': [True, 0], 'add_filters': False, 'add_filters_dict': {'names': [], 'filenames': [], 'freq/wl_format': [], 'freq/wl_unit': [], 'description': []}}
# Models settings:  {'path': 'models/', 'modelset': 'modelsv1', 'GALAXY': 'BC03_metal', 'STARBURST': 'S17', 'BBB': 'THB21', 'TORUS': 'SKIRTOR_1P', 'XRAYS': False, 'RADIO': False, 'Blazar': 'None', 'PRIOR_energy_balance': 'Flexible', 'PRIOR_AGNfraction': True, 'PRIOR_midIR_UV': False, 'PRIOR_galaxy_only': False, 'turn_on_AGN': True}
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}

# %%
import os
import subprocess
import matplotlib.pyplot as plt

# Disable LaTeX
plt.rcParams['text.usetex'] = False

# Optionally, configure the font to avoid using LaTeX-style fonts
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Arial']

# Define the paths
agnfitter_path = 'C:\\Users\\PC\\AGNfitter\\'
settings_file_name = 'SETTINGS_AGNfitter.py'
settings_file_path = os.path.join(agnfitter_path, settings_file_name)

# Create the required directory
required_directory = os.path.join(agnfitter_path, 'OUTPUT', 'Mrk493')
if not os.path.exists(required_directory):
    os.makedirs(required_directory)
    print(f"Created directory: {required_directory}")
else:
    print(f"Directory already exists: {required_directory}")

# Print the settings file path
print("Settings File Path: ", settings_file_path)

# Command to run the AGNfitter script
command = ['python', os.path.join(agnfitter_path, 'RUN_AGNfitter_multi.py'), settings_file_path]

# Run the command and capture output
try:
    result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    print("AGNfitter script ran successfully.")
    print(result.stdout)
except subprocess.CalledProcessError as e:
    print("Error running AGNfitter script:")
    print(e.stderr)
    print(e.stdout)
# Out:
# Directory already exists: C:\Users\PC\AGNfitter\OUTPUT\Mrk493
# Settings File Path:  C:\Users\PC\AGNfitter\SETTINGS_AGNfitter.py
# Error running AGNfitter script:
# Traceback (most recent call last):
#   File "C:\Users\PC\AGNfitter\RUN_AGNfitter_multi.py", line 301, in <module>
#     data_ALL.PROPS()
#   File "C:\Users\PC\AGNfitter\functions\DATA_AGNfitter.py", line 103, in PROPS
#     np.array(column.iloc[:, self.cat['flux_list']]).astype(np.float6464) * self.cat['flux_unit']
#                                                            ^^^^^^^^^^^^
#   File "C:\Users\PC\anaconda3\Lib\site-packages\numpy\__init__.py", line 320, in __getattr__
#     raise AttributeError("module {!r} has no attribute "
# AttributeError: module 'numpy' has no attribute 'float6464'. Did you mean: 'float64'?
#
#
#              XXXX
# ___________ XXX _________________________________________________
#             XX
#             X
#             X                       AGNfitter
#          __ X __                    ---------
#      /**\   |   /**\
# ... (*** =  o  = ***) ...........................................
#      \**/__ | __\**/
#             X              Fitting SEDs of AGN and Galaxies
#             X             in a MCMC Approach
#            xx              (Calistro Rivera et al. 2016)
#           xx
# _______ xxx______________________________________________________
#      xxxx
#
# Catalog settings:  {'path': 'C:\\Users\\PC\\AGNfitter\\', 'filename': 'C:\\Users\\PC\\AGNfitter\\catalog_example.txt', 'filetype': 'ASCII', 'name': 0, 'redshift': 1, 'freq/wl_list': [2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74, 77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137, 140, 143, 146], 'use_central_wavelength': True, 'freq/wl_format': 'wavelength', 'freq/wl_unit': Unit("micron"), 'flux_in_magAB': False, 'flux_unit': <Quantity 0.001 Jy>, 'flux_list': [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147], 'fluxerr_list': [4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70, 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 103, 106, 109, 112, 115, 118, 121, 124, 127, 130, 133, 136, 139, 142, 145, 148], 'err+10%flux_moreflex': False, 'ndflag_bool': False, 'ndflag_list': 'list', 'workingpath': 'C:\\Users\\PC\\AGNfitter\\', 'output_folder': 'C:\\Users\\PC\\AGNfitter\\OUTPUT/'}
# Filters settings:  {'dict_zarray': array([], dtype=float64), 'path': 'models/FILTERS/', 'filterset': 'example_46datapointa', '4XMM_EP5': [True, 48], '4XMM_EP4': [True, 47], '4XMM_EP3': [True, 46], '4XMM_EP2': [True, 45], 'RAD_1_4GHz': [True, 44], 'RAD_5GHz': [True, 43], 'RAD_15GHz': [True, 42], 'SPIRE500': [True, 41], 'SPIRE350': [True, 40], 'SPIRE250': [True, 39], 'PACS160': [True, 38], 'PACS100': [True, 37], 'PACS70': [True, 36], 'M1': [True, 35], 'WISE4': [True, 34], 'WISE3': [True, 33], 'IRAC4': [True, 32], 'IRAC3': [True, 31], 'WISE2': [True, 30], 'IRAC2': [True, 29], 'IRAC1': [True, 28], 'WISE1': [True, 27], 'Ks_2mass': [True, 26], 'H_2mass': [True, 25], 'J_2mass': [True, 24], 'y_PS1_good': [True, 23], 'SKY_z': [True, 22], 'z': [True, 21], 'z_PS1': [True, 20], 'SKY_i': [True, 19], 'i_PS1': [True, 18], 'i': [True, 17], 'SKY_r': [True, 16], 'r_PS1': [True, 15], 'r': [True, 14], 'SWIFT_V': [True, 13], 'SKY_g': [True, 12], 'g_PS1': [True, 11], 'g': [True, 10], 'SWIFT_B': [True, 9], 'SKY_v': [True, 8], 'u': [True, 7], 'SKY_u': [True, 6], 'SWIFT_U': [True, 5], 'SWIFT_W1': [True, 4], 'GALEX_2500': [True, 3], 'SWIFT_M2': [True, 2], 'SWIFT_W2': [True, 1], 'GALEX_1500': [True, 0], 'add_filters': False, 'add_filters_dict': {'names': [], 'filenames': [], 'freq/wl_format': [], 'freq/wl_unit': [], 'description': []}}
# Models settings:  {'path': 'models/', 'modelset': 'modelsv1', 'GALAXY': 'BC03_metal', 'STARBURST': 'S17', 'BBB': 'THB21', 'TORUS': 'SKIRTOR_1P', 'XRAYS': False, 'RADIO': False, 'Blazar': 'None', 'PRIOR_energy_balance': 'Flexible', 'PRIOR_AGNfraction': True, 'PRIOR_midIR_UV': False, 'PRIOR_galaxy_only': False, 'turn_on_AGN': True}
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}

# %%
import os
import subprocess

# Define the paths
agnfitter_path = 'C:\\Users\\PC\\AGNfitter\\'
settings_file_name = 'SETTINGS_AGNfitter.py'
settings_file_path = os.path.join(agnfitter_path, settings_file_name)

# Create the required directory
required_directory = os.path.join(agnfitter_path, 'OUTPUT', 'Mrk493')
if not os.path.exists(required_directory):
    os.makedirs(required_directory)
    print(f"Created directory: {required_directory}")
else:
    print(f"Directory already exists: {required_directory}")

# Print the settings file path
print("Settings File Path: ", settings_file_path)

# Command to run the AGNfitter script
command = ['python', os.path.join(agnfitter_path, 'RUN_AGNfitter_multi.py'), settings_file_path]

# Run the command and capture output
try:
    result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    print("AGNfitter script ran successfully.")
    print(result.stdout)
except subprocess.CalledProcessError as e:
    print("Error running AGNfitter script:")
    print(e.stderr)
    print(e.stdout)
# Out:
# Directory already exists: C:\Users\PC\AGNfitter\OUTPUT\Mrk493
# Settings File Path:  C:\Users\PC\AGNfitter\SETTINGS_AGNfitter.py
# Error running AGNfitter script:
# Traceback (most recent call last):
#   File "C:\Users\PC\AGNfitter\RUN_AGNfitter_multi.py", line 301, in <module>
#     data_ALL.PROPS()
#   File "C:\Users\PC\AGNfitter\functions\DATA_AGNfitter.py", line 103, in PROPS
#     np.array(column.iloc[:, self.cat['flux_list']]).astype(np.float6464) * self.cat['flux_unit']
#                                                            ^^^^^^^^^^^^
#   File "C:\Users\PC\anaconda3\Lib\site-packages\numpy\__init__.py", line 320, in __getattr__
#     raise AttributeError("module {!r} has no attribute "
# AttributeError: module 'numpy' has no attribute 'float6464'. Did you mean: 'float64'?
#
#
#              XXXX
# ___________ XXX _________________________________________________
#             XX
#             X
#             X                       AGNfitter
#          __ X __                    ---------
#      /**\   |   /**\
# ... (*** =  o  = ***) ...........................................
#      \**/__ | __\**/
#             X              Fitting SEDs of AGN and Galaxies
#             X             in a MCMC Approach
#            xx              (Calistro Rivera et al. 2016)
#           xx
# _______ xxx______________________________________________________
#      xxxx
#
# Catalog settings:  {'path': 'C:\\Users\\PC\\AGNfitter\\', 'filename': 'C:\\Users\\PC\\AGNfitter\\catalog_example.txt', 'filetype': 'ASCII', 'name': 0, 'redshift': 1, 'freq/wl_list': [2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74, 77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137, 140, 143, 146], 'use_central_wavelength': True, 'freq/wl_format': 'wavelength', 'freq/wl_unit': Unit("micron"), 'flux_in_magAB': False, 'flux_unit': <Quantity 0.001 Jy>, 'flux_list': [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147], 'fluxerr_list': [4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70, 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 103, 106, 109, 112, 115, 118, 121, 124, 127, 130, 133, 136, 139, 142, 145, 148], 'err+10%flux_moreflex': False, 'ndflag_bool': False, 'ndflag_list': 'list', 'workingpath': 'C:\\Users\\PC\\AGNfitter\\', 'output_folder': 'C:\\Users\\PC\\AGNfitter\\OUTPUT/'}
# Filters settings:  {'dict_zarray': array([], dtype=float64), 'path': 'models/FILTERS/', 'filterset': 'example_46datapointa', '4XMM_EP5': [True, 48], '4XMM_EP4': [True, 47], '4XMM_EP3': [True, 46], '4XMM_EP2': [True, 45], 'RAD_1_4GHz': [True, 44], 'RAD_5GHz': [True, 43], 'RAD_15GHz': [True, 42], 'SPIRE500': [True, 41], 'SPIRE350': [True, 40], 'SPIRE250': [True, 39], 'PACS160': [True, 38], 'PACS100': [True, 37], 'PACS70': [True, 36], 'M1': [True, 35], 'WISE4': [True, 34], 'WISE3': [True, 33], 'IRAC4': [True, 32], 'IRAC3': [True, 31], 'WISE2': [True, 30], 'IRAC2': [True, 29], 'IRAC1': [True, 28], 'WISE1': [True, 27], 'Ks_2mass': [True, 26], 'H_2mass': [True, 25], 'J_2mass': [True, 24], 'y_PS1_good': [True, 23], 'SKY_z': [True, 22], 'z': [True, 21], 'z_PS1': [True, 20], 'SKY_i': [True, 19], 'i_PS1': [True, 18], 'i': [True, 17], 'SKY_r': [True, 16], 'r_PS1': [True, 15], 'r': [True, 14], 'SWIFT_V': [True, 13], 'SKY_g': [True, 12], 'g_PS1': [True, 11], 'g': [True, 10], 'SWIFT_B': [True, 9], 'SKY_v': [True, 8], 'u': [True, 7], 'SKY_u': [True, 6], 'SWIFT_U': [True, 5], 'SWIFT_W1': [True, 4], 'GALEX_2500': [True, 3], 'SWIFT_M2': [True, 2], 'SWIFT_W2': [True, 1], 'GALEX_1500': [True, 0], 'add_filters': False, 'add_filters_dict': {'names': [], 'filenames': [], 'freq/wl_format': [], 'freq/wl_unit': [], 'description': []}}
# Models settings:  {'path': 'models/', 'modelset': 'modelsv1', 'GALAXY': 'BC03_metal', 'STARBURST': 'S17', 'BBB': 'THB21', 'TORUS': 'SKIRTOR_1P', 'XRAYS': False, 'RADIO': False, 'Blazar': 'None', 'PRIOR_energy_balance': 'Flexible', 'PRIOR_AGNfraction': True, 'PRIOR_midIR_UV': False, 'PRIOR_galaxy_only': False, 'turn_on_AGN': True}
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}

# %%
import matplotlib.pyplot as plt

# Disable LaTeX
plt.rcParams['text.usetex'] = False

# Optionally, configure the font to avoid using LaTeX-style fonts
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Arial']

# Re-run your AGNfitter script
import os
import subprocess

# Define the paths
agnfitter_path = 'C:\\Users\\PC\\AGNfitter\\'
settings_file_name = 'SETTINGS_AGNfitter.py'
settings_file_path = os.path.join(agnfitter_path, settings_file_name)

# Create the required directory
required_directory = os.path.join(agnfitter_path, 'OUTPUT', 'Mrk493')
if not os.path.exists(required_directory):
    os.makedirs(required_directory)
    print(f"Created directory: {required_directory}")
else:
    print(f"Directory already exists: {required_directory}")

# Print the settings file path
print("Settings File Path: ", settings_file_path)

# Command to run the AGNfitter script
command = ['python', os.path.join(agnfitter_path, 'RUN_AGNfitter_multi.py'), settings_file_path]

# Run the command and capture output
try:
    result = subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    print("AGNfitter script ran successfully.")
    print(result.stdout)
except subprocess.CalledProcessError as e:
    print("Error running AGNfitter script:")
    print(e.stderr)
    print(e.stdout)
# Out:
# Directory already exists: C:\Users\PC\AGNfitter\OUTPUT\Mrk493
# Settings File Path:  C:\Users\PC\AGNfitter\SETTINGS_AGNfitter.py
# AGNfitter script ran successfully.
#
#              XXXX
# ___________ XXX _________________________________________________
#             XX
#             X
#             X                       AGNfitter
#          __ X __                    ---------
#      /**\   |   /**\
# ... (*** =  o  = ***) ...........................................
#      \**/__ | __\**/
#             X              Fitting SEDs of AGN and Galaxies
#             X             in a MCMC Approach
#            xx              (Calistro Rivera et al. 2016)
#           xx
# _______ xxx______________________________________________________
#      xxxx
#
# Catalog settings:  {'path': 'C:\\Users\\PC\\AGNfitter\\', 'filename': 'C:\\Users\\PC\\AGNfitter\\catalog_example.txt', 'filetype': 'ASCII', 'name': 0, 'redshift': 1, 'freq/wl_list': [2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74, 77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137, 140, 143, 146], 'use_central_wavelength': True, 'freq/wl_format': 'wavelength', 'freq/wl_unit': Unit("micron"), 'flux_in_magAB': False, 'flux_unit': <Quantity 0.001 Jy>, 'flux_list': [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147], 'fluxerr_list': [4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70, 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 103, 106, 109, 112, 115, 118, 121, 124, 127, 130, 133, 136, 139, 142, 145, 148], 'err+10%flux_moreflex': False, 'ndflag_bool': False, 'ndflag_list': 'list', 'workingpath': 'C:\\Users\\PC\\AGNfitter\\', 'output_folder': 'C:\\Users\\PC\\AGNfitter\\OUTPUT/'}
# Filters settings:  {'dict_zarray': array([], dtype=float64), 'path': 'models/FILTERS/', 'filterset': 'example_46datapointa', '4XMM_EP5': [True, 48], '4XMM_EP4': [True, 47], '4XMM_EP3': [True, 46], '4XMM_EP2': [True, 45], 'RAD_1_4GHz': [True, 44], 'RAD_5GHz': [True, 43], 'RAD_15GHz': [True, 42], 'SPIRE500': [True, 41], 'SPIRE350': [True, 40], 'SPIRE250': [True, 39], 'PACS160': [True, 38], 'PACS100': [True, 37], 'PACS70': [True, 36], 'M1': [True, 35], 'WISE4': [True, 34], 'WISE3': [True, 33], 'IRAC4': [True, 32], 'IRAC3': [True, 31], 'WISE2': [True, 30], 'IRAC2': [True, 29], 'IRAC1': [True, 28], 'WISE1': [True, 27], 'Ks_2mass': [True, 26], 'H_2mass': [True, 25], 'J_2mass': [True, 24], 'y_PS1_good': [True, 23], 'SKY_z': [True, 22], 'z': [True, 21], 'z_PS1': [True, 20], 'SKY_i': [True, 19], 'i_PS1': [True, 18], 'i': [True, 17], 'SKY_r': [True, 16], 'r_PS1': [True, 15], 'r': [True, 14], 'SWIFT_V': [True, 13], 'SKY_g': [True, 12], 'g_PS1': [True, 11], 'g': [True, 10], 'SWIFT_B': [True, 9], 'SKY_v': [True, 8], 'u': [True, 7], 'SKY_u': [True, 6], 'SWIFT_U': [True, 5], 'SWIFT_W1': [True, 4], 'GALEX_2500': [True, 3], 'SWIFT_M2': [True, 2], 'SWIFT_W2': [True, 1], 'GALEX_1500': [True, 0], 'add_filters': False, 'add_filters_dict': {'names': [], 'filenames': [], 'freq/wl_format': [], 'freq/wl_unit': [], 'description': []}}
# Models settings:  {'path': 'models/', 'modelset': 'modelsv1', 'GALAXY': 'BC03_metal', 'STARBURST': 'S17', 'BBB': 'THB21', 'TORUS': 'SKIRTOR_1P', 'XRAYS': False, 'RADIO': False, 'Blazar': 'None', 'PRIOR_energy_balance': 'Flexible', 'PRIOR_AGNfraction': True, 'PRIOR_midIR_UV': False, 'PRIOR_galaxy_only': False, 'turn_on_AGN': True}
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Option of one single dictionary for a whole catalogue is deprecated. Running "independent, -i" option.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  0
# - Sourcename:  Mrk493
# Done
#  => SEDs of 10 different realization were plotted.
# MCMC settings:  {'sampling_algorithm': 'ultranest', 'Nwalkers': 100, 'Nburnsets': 2, 'Nburn': 12000, 'Nmcmc': 25000, 'iprint': 1000, 'direction_generation': 'de-mix', 'live_points': 400, 'min_ess': 400, 'num_loops': 0}
# Output settings:  {'plot_format': 'pdf', 'band_indicators': True, 'realizations_format': 'shaded', 'plot_tracesburn-in': False, 'plot_tracesmcmc': True, 'Nsample': 1000, 'Nthinning': 10, 'writepar_meanwitherrors': True, 'plot_posteriortriangle': True, 'calc_intlum': True, 'save_posterior_luminosities': False, 'save_posteriors': True, 'realizations2int': 100, 'plot_posteriortrianglewithluminosities': False, 'intlum_models': ['sb', 'bbb', 'bbbdered', 'gal', 'AGNfrac_opt', 'tor', 'tor+bbb', 'AGNfrac_IR', 'gal', 'bbb', 'AGNfrac_opt', 'tor', 'sb'], 'intlum_freqranges_unit': Unit("micron"), 'intlum_freqranges': array([[8.e+00, 1.e+03],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e-01, 1.e+00],
#        [1.e+00, 3.e+01],
#        [1.e-01, 3.e+01],
#        [8.e+00, 1.e+03],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [4.e-01, 5.e-01],
#        [6.e+00, 6.e+00],
#        [1.e+00, 3.e+01]]), 'intlum_names': ['LIR(8-1000)', 'Lbb(0.1-1)', 'Lbbdered(0.1-1)', 'Lga(01-1)', 'AGNfrac(0.1-1)', 'Ltor(1-30)', 'LAGN(0.1-30)', 'AGNfrac(8-1000)', 'Lgal(0.4-0.5)', 'Lbbb(0.4-0.5)', 'AGNfrac(0.4-0.5)', 'Ltor(6)', 'Lsb(1-30)'], 'realizations2plot': 10, 'plot_best_fit': True, 'plot_median_fit': False, 'plot_residuals': True, 'saveSEDresiduals': True, 'plotSEDrealizations': True, 'saveSEDrealizations': True}
#
# ________________________
# Fitting sources from catalog:  C:\Users\PC\AGNfitter\catalog_example.txt
# - Sourceline:  1
# - Sourcename:  Mrk876
# Done
#  => SEDs of 10 different realization were plotted.
# ======= : =======
# Process finished.
